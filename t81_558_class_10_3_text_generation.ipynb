# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_10_3_text_generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # T81-558: Applications of Deep Neural Networks
# **Module 10: Time Series in Keras**
# * Instructor: [Jeff Heaton](https://sites.wustl.edu/jeffheaton/), McKelvey School of Engineering, [Washington University in St. Louis](https://engineering.wustl.edu/Programs/Pages/default.aspx)
# * For more information visit the [class website](https://sites.wustl.edu/jeffheaton/t81-558/).

# %% [markdown]
# # Module 10 Material
#
# * Part 10.1: Time Series Data Encoding for Deep Learning [[Video]](https://www.youtube.com/watch?v=dMUmHsktl04&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_10_1_timeseries.ipynb)
# * Part 10.2: Programming LSTM with Keras and TensorFlow [[Video]](https://www.youtube.com/watch?v=wY0dyFgNCgY&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_10_2_lstm.ipynb)
# * **Part 10.3: Text Generation with Keras and TensorFlow** [[Video]](https://www.youtube.com/watch?v=6ORnRAz3gnA&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_10_3_text_generation.ipynb)
# * Part 10.4: Introduction to Transformers [[Video]](https://www.youtube.com/watch?v=Z7FIdKVQ7kc&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_10_4_intro_transformers.ipynb)
# * Part 10.5: Transformers for Timeseries [[Video]](https://www.youtube.com/watch?v=SX67Mni0Or4&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_10_5_keras_transformers.ipynb)

# %% [markdown]
# # Google CoLab Instructions
#
# The following code ensures that Google CoLab is running the correct version of TensorFlow.

# %%
try:
    # %tensorflow_version 2.x
    COLAB = True
    print("Note: using Google CoLab")
except:
    print("Note: not using Google CoLab")
    COLAB = False
# Out:
# Note: using Google CoLab

# %% [markdown]
# # Part 10.3: Text Generation with LSTM
#
# Recurrent neural networks are also known for their ability to generate text. As a result, the neural network's output can be free-form text. This section will demonstrate how to train an LSTM on a textual document, such as classic literature, and learn to output new text that appears to be of the same form as the training material. If you train your LSTM on [Shakespeare](https://en.wikipedia.org/wiki/William_Shakespeare), it will learn to crank out new prose similar to what Shakespeare had written.
#
# Don't get your hopes up. You will not teach your deep neural network to write the next [Pulitzer Prize for Fiction](https://en.wikipedia.org/wiki/Pulitzer_Prize_for_Fiction). The prose generated by your neural network will be nonsensical. However, the output text will usually be nearly grammatically correct and similar to the source training documents.
#
# A neural network generating nonsensical text based on literature may not seem helpful. However, this technology gets so much interest because it forms the foundation for many more advanced technologies. The LSTM will typically learn human grammar from the source document opens a wide range of possibilities. You can use similar technology to complete sentences when entering text. **The ability to output free-form text has become the foundation of many other technologies.** In the next part, we will use this technique to create a neural network that can write captions for images to describe what is going on in the picture.
#
# ## Additional Information
#
# The following are some articles that I found helpful in putting this section together.
#
# * [The Unreasonable Effectiveness of Recurrent Neural Networks](http://karpathy.github.io/2015/05/21/rnn-effectiveness/)
# * [Keras LSTM Generation Example](https://keras.io/examples/lstm_text_generation/)
#
# ## Character-Level Text Generation
#
# There are several different approaches to teaching a neural network to output free-form text. The most basic question is if you wish the neural network to learn at the word or character level. Learning at the character level is the more interesting of the two. The LSTM is learning to construct its own words without even being shown what a word is. We will begin with character-level text generation. In the next module, we will see how we can use nearly the same technique to operate at the word level. We will implement word-level automatic captioning in the next module.
#
# We import the needed Python packages and define the sequence length, named **maxlen**. Time-series neural networks always accept their input as a fixed-length array. Because you might not use all of the sequence elements, filling extra pieces with zeros is common. You will divide the text into sequences of this length, and the neural network will train to predict what comes after this sequence.

# %%
from tensorflow.keras.callbacks import LambdaCallback
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import get_file
import numpy as np
import random
import sys
import io
import requests
import re

# %% [markdown]
# We will train the neural network on the classic children's book [Treasure Island](https://en.wikipedia.org/wiki/Treasure_Island).  We begin by loading this text into a Python string and displaying the first 1,000 characters.

# %%
r = requests.get("https://data.heatonresearch.com/data/t81-558/text/"\
                 "treasure_island.txt")
raw_text = r.text
print(raw_text[0:1000])
# Out:
# ï»¿The Project Gutenberg EBook of Treasure Island, by Robert Louis Stevenson
#
# This eBook is for the use of anyone anywhere at no cost and with
# almost no restrictions whatsoever.  You may copy it, give it away or
# re-use it under the terms of the Project Gutenberg License included
# with this eBook or online at www.gutenberg.net
#
#
# Title: Treasure Island
#
# Author: Robert Louis Stevenson
#
# Illustrator: Milo Winter
#
# Release Date: January 12, 2009 [EBook #27780]
#
# Language: English
#
#
# *** START OF THIS PROJECT GUTENBERG EBOOK TREASURE ISLAND ***
#
#
#
#
# Produced by Juliet Sutherland, Stephen Blundell and the
# Online Distributed Proofreading Team at http://www.pgdp.net
#
#
#
#
#
#
#
#
#
#  THE ILLUSTRATED CHILDREN'S LIBRARY
#
#
#          _Treasure Island_
#
#        Robert Louis Stevenson
#
#           _Illustrated by_
#             Milo Winter
#
#
#            [Illustration]
#
#
#            GRAMERCY BOOKS
#               NEW YORK
#
#
#
#
#  Foreword copyright Â© 1986 by Random House V

# %% [markdown]
# We will extract all unique characters from the text and sort them.  This technique allows us to assign a unique ID to each character.  Because we sorted the characters, these IDs should remain the same.  The IDs will change if we add new characters to the original text.  We build two dictionaries.  The first **char2idx** is used to convert a character into its ID.  The second **idx2char** converts an ID back into its character.

# %%
processed_text = raw_text.lower()
processed_text = re.sub(r'[^\x00-\x7f]',r'', processed_text) 

print('corpus length:', len(processed_text))

chars = sorted(list(set(processed_text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# corpus length: 397400
# total chars: 60

# %% [markdown]
# We are now ready to build the actual sequences.  Like previous neural networks, there will be an $x$ and $y$.  However, for the LSTM, $x$ and $y$ will be sequences.  The $x$ input will specify the sequences where $y$ is the expected output.  The following code generates all possible sequences.

# %%
# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(processed_text) - maxlen, step):
    sentences.append(processed_text[i: i + maxlen])
    next_chars.append(processed_text[i + maxlen])
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 132454

# %%
sentences
# Out:
# ['the project gutenberg ebook of treasure ',
#  ' project gutenberg ebook of treasure isl',
#  'oject gutenberg ebook of treasure island',
#  'ct gutenberg ebook of treasure island, b',
#  'gutenberg ebook of treasure island, by r',
#  'enberg ebook of treasure island, by robe',
#  'erg ebook of treasure island, by robert ',
#  ' ebook of treasure island, by robert lou',
#  'ook of treasure island, by robert louis ',
#  ' of treasure island, by robert louis ste',
#  ' treasure island, by robert louis steven',
#  'easure island, by robert louis stevenson',
#  'ure island, by robert louis stevenson\r\n\r',
#  ' island, by robert louis stevenson\r\n\r\nth',
#  'land, by robert louis stevenson\r\n\r\nthis ',
#  'd, by robert louis stevenson\r\n\r\nthis ebo',
#  'by robert louis stevenson\r\n\r\nthis ebook ',
#  'robert louis stevenson\r\n\r\nthis ebook is ',
#  'ert louis stevenson\r\n\r\nthis ebook is for',
#  ' louis stevenson\r\n\r\nthis ebook is for th',
#  'uis stevenson\r\n\r\nthis ebook is for the u',
#  ' stevenson\r\n\r\nthis ebook is for the use ',
#  'evenson\r\n\r\nthis ebook is for the use of ',
#  'nson\r\n\r\nthis ebook is for the use of any',
#  'n\r\n\r\nthis ebook is for the use of anyone',
#  '\r\nthis ebook is for the use of anyone an',
#  'his ebook is for the use of anyone anywh',
#  ' ebook is for the use of anyone anywhere',
#  'ook is for the use of anyone anywhere at',
#  ' is for the use of anyone anywhere at no',
#  ' for the use of anyone anywhere at no co',
#  'r the use of anyone anywhere at no cost ',
#  'he use of anyone anywhere at no cost and',
#  'use of anyone anywhere at no cost and wi',
#  ' of anyone anywhere at no cost and with\r',
#  ' anyone anywhere at no cost and with\r\nal',
#  'yone anywhere at no cost and with\r\nalmos',
#  'e anywhere at no cost and with\r\nalmost n',
#  'nywhere at no cost and with\r\nalmost no r',
#  'here at no cost and with\r\nalmost no rest',
#  'e at no cost and with\r\nalmost no restric',
#  't no cost and with\r\nalmost no restrictio',
#  'o cost and with\r\nalmost no restrictions ',
#  'ost and with\r\nalmost no restrictions wha',
#  ' and with\r\nalmost no restrictions whatso',
#  'd with\r\nalmost no restrictions whatsoeve',
#  'ith\r\nalmost no restrictions whatsoever. ',
#  '\r\nalmost no restrictions whatsoever.  yo',
#  'lmost no restrictions whatsoever.  you m',
#  'st no restrictions whatsoever.  you may ',
#  'no restrictions whatsoever.  you may cop',
#  'restrictions whatsoever.  you may copy i',
#  'trictions whatsoever.  you may copy it, ',
#  'ctions whatsoever.  you may copy it, giv',
#  'ons whatsoever.  you may copy it, give i',
#  ' whatsoever.  you may copy it, give it a',
#  'atsoever.  you may copy it, give it away',
#  'oever.  you may copy it, give it away or',
#  'er.  you may copy it, give it away or\r\nr',
#  '  you may copy it, give it away or\r\nre-u',
#  'ou may copy it, give it away or\r\nre-use ',
#  'may copy it, give it away or\r\nre-use it ',
#  ' copy it, give it away or\r\nre-use it und',
#  'py it, give it away or\r\nre-use it under ',
#  'it, give it away or\r\nre-use it under the',
#  ' give it away or\r\nre-use it under the te',
#  've it away or\r\nre-use it under the terms',
#  'it away or\r\nre-use it under the terms of',
#  'away or\r\nre-use it under the terms of th',
#  'y or\r\nre-use it under the terms of the p',
#  'r\r\nre-use it under the terms of the proj',
#  're-use it under the terms of the project',
#  'use it under the terms of the project gu',
#  ' it under the terms of the project guten',
#  ' under the terms of the project gutenber',
#  'der the terms of the project gutenberg l',
#  ' the terms of the project gutenberg lice',
#  'e terms of the project gutenberg license',
#  'erms of the project gutenberg license in',
#  's of the project gutenberg license inclu',
#  'f the project gutenberg license included',
#  'he project gutenberg license included\r\nw',
#  'project gutenberg license included\r\nwith',
#  'ject gutenberg license included\r\nwith th',
#  't gutenberg license included\r\nwith this ',
#  'utenberg license included\r\nwith this ebo',
#  'nberg license included\r\nwith this ebook ',
#  'rg license included\r\nwith this ebook or ',
#  'license included\r\nwith this ebook or onl',
#  'ense included\r\nwith this ebook or online',
#  'e included\r\nwith this ebook or online at',
#  'ncluded\r\nwith this ebook or online at ww',
#  'uded\r\nwith this ebook or online at www.g',
#  'd\r\nwith this ebook or online at www.gute',
#  'with this ebook or online at www.gutenbe',
#  'h this ebook or online at www.gutenberg.',
#  'his ebook or online at www.gutenberg.net',
#  ' ebook or online at www.gutenberg.net\r\n\r',
#  'ook or online at www.gutenberg.net\r\n\r\n\r\n',
#  ' or online at www.gutenberg.net\r\n\r\n\r\ntit',
#  ' online at www.gutenberg.net\r\n\r\n\r\ntitle:',
#  'line at www.gutenberg.net\r\n\r\n\r\ntitle: tr',
#  'e at www.gutenberg.net\r\n\r\n\r\ntitle: treas',
#  't www.gutenberg.net\r\n\r\n\r\ntitle: treasure',
#  'ww.gutenberg.net\r\n\r\n\r\ntitle: treasure is',
#  'gutenberg.net\r\n\r\n\r\ntitle: treasure islan',
#  'enberg.net\r\n\r\n\r\ntitle: treasure island\r\n',
#  'erg.net\r\n\r\n\r\ntitle: treasure island\r\n\r\na',
#  '.net\r\n\r\n\r\ntitle: treasure island\r\n\r\nauth',
#  't\r\n\r\n\r\ntitle: treasure island\r\n\r\nauthor:',
#  '\r\n\r\ntitle: treasure island\r\n\r\nauthor: ro',
#  '\ntitle: treasure island\r\n\r\nauthor: rober',
#  'tle: treasure island\r\n\r\nauthor: robert l',
#  ': treasure island\r\n\r\nauthor: robert loui',
#  'reasure island\r\n\r\nauthor: robert louis s',
#  'sure island\r\n\r\nauthor: robert louis stev',
#  'e island\r\n\r\nauthor: robert louis stevens',
#  'sland\r\n\r\nauthor: robert louis stevenson\r',
#  'nd\r\n\r\nauthor: robert louis stevenson\r\n\r\n',
#  '\n\r\nauthor: robert louis stevenson\r\n\r\nill',
#  'author: robert louis stevenson\r\n\r\nillust',
#  'hor: robert louis stevenson\r\n\r\nillustrat',
#  ': robert louis stevenson\r\n\r\nillustrator:',
#  'obert louis stevenson\r\n\r\nillustrator: mi',
#  'rt louis stevenson\r\n\r\nillustrator: milo ',
#  'louis stevenson\r\n\r\nillustrator: milo win',
#  'is stevenson\r\n\r\nillustrator: milo winter',
#  'stevenson\r\n\r\nillustrator: milo winter\r\n\r',
#  'venson\r\n\r\nillustrator: milo winter\r\n\r\nre',
#  'son\r\n\r\nillustrator: milo winter\r\n\r\nrelea',
#  '\r\n\r\nillustrator: milo winter\r\n\r\nrelease ',
#  '\nillustrator: milo winter\r\n\r\nrelease dat',
#  'lustrator: milo winter\r\n\r\nrelease date: ',
#  'trator: milo winter\r\n\r\nrelease date: jan',
#  'tor: milo winter\r\n\r\nrelease date: januar',
#  ': milo winter\r\n\r\nrelease date: january 1',
#  'ilo winter\r\n\r\nrelease date: january 12, ',
#  ' winter\r\n\r\nrelease date: january 12, 200',
#  'nter\r\n\r\nrelease date: january 12, 2009 [',
#  'r\r\n\r\nrelease date: january 12, 2009 [ebo',
#  '\r\nrelease date: january 12, 2009 [ebook ',
#  'elease date: january 12, 2009 [ebook #27',
#  'ase date: january 12, 2009 [ebook #27780',
#  ' date: january 12, 2009 [ebook #27780]\r\n',
#  'te: january 12, 2009 [ebook #27780]\r\n\r\nl',
#  ' january 12, 2009 [ebook #27780]\r\n\r\nlang',
#  'nuary 12, 2009 [ebook #27780]\r\n\r\nlanguag',
#  'ry 12, 2009 [ebook #27780]\r\n\r\nlanguage: ',
#  '12, 2009 [ebook #27780]\r\n\r\nlanguage: eng',
#  ' 2009 [ebook #27780]\r\n\r\nlanguage: englis',
#  '09 [ebook #27780]\r\n\r\nlanguage: english\r\n',
#  '[ebook #27780]\r\n\r\nlanguage: english\r\n\r\n\r',
#  'ook #27780]\r\n\r\nlanguage: english\r\n\r\n\r\n**',
#  ' #27780]\r\n\r\nlanguage: english\r\n\r\n\r\n*** s',
#  '7780]\r\n\r\nlanguage: english\r\n\r\n\r\n*** star',
#  '0]\r\n\r\nlanguage: english\r\n\r\n\r\n*** start o',
#  '\n\r\nlanguage: english\r\n\r\n\r\n*** start of t',
#  'language: english\r\n\r\n\r\n*** start of this',
#  'guage: english\r\n\r\n\r\n*** start of this pr',
#  'ge: english\r\n\r\n\r\n*** start of this proje',
#  ' english\r\n\r\n\r\n*** start of this project ',
#  'glish\r\n\r\n\r\n*** start of this project gut',
#  'sh\r\n\r\n\r\n*** start of this project gutenb',
#  '\n\r\n\r\n*** start of this project gutenberg',
#  '\r\n*** start of this project gutenberg eb',
#  '** start of this project gutenberg ebook',
#  'start of this project gutenberg ebook tr',
#  'rt of this project gutenberg ebook treas',
#  'of this project gutenberg ebook treasure',
#  'this project gutenberg ebook treasure is',
#  's project gutenberg ebook treasure islan',
#  'roject gutenberg ebook treasure island *',
#  'ect gutenberg ebook treasure island ***\r',
#  ' gutenberg ebook treasure island ***\r\n\r\n',
#  'tenberg ebook treasure island ***\r\n\r\n\r\n\r',
#  'berg ebook treasure island ***\r\n\r\n\r\n\r\n\r\n',
#  'g ebook treasure island ***\r\n\r\n\r\n\r\n\r\npro',
#  'book treasure island ***\r\n\r\n\r\n\r\n\r\nproduc',
#  'k treasure island ***\r\n\r\n\r\n\r\n\r\nproduced ',
#  'reasure island ***\r\n\r\n\r\n\r\n\r\nproduced by ',
#  'sure island ***\r\n\r\n\r\n\r\n\r\nproduced by jul',
#  'e island ***\r\n\r\n\r\n\r\n\r\nproduced by juliet',
#  'sland ***\r\n\r\n\r\n\r\n\r\nproduced by juliet su',
#  'nd ***\r\n\r\n\r\n\r\n\r\nproduced by juliet suthe',
#  '***\r\n\r\n\r\n\r\n\r\nproduced by juliet sutherla',
#  '\r\n\r\n\r\n\r\n\r\nproduced by juliet sutherland,',
#  '\n\r\n\r\n\r\nproduced by juliet sutherland, st',
#  '\r\n\r\nproduced by juliet sutherland, steph',
#  '\nproduced by juliet sutherland, stephen ',
#  'oduced by juliet sutherland, stephen blu',
#  'ced by juliet sutherland, stephen blunde',
#  ' by juliet sutherland, stephen blundell ',
#  ' juliet sutherland, stephen blundell and',
#  'liet sutherland, stephen blundell and th',
#  't sutherland, stephen blundell and the\r\n',
#  'utherland, stephen blundell and the\r\nonl',
#  'erland, stephen blundell and the\r\nonline',
#  'and, stephen blundell and the\r\nonline di',
#  ', stephen blundell and the\r\nonline distr',
#  'tephen blundell and the\r\nonline distribu',
#  'hen blundell and the\r\nonline distributed',
#  ' blundell and the\r\nonline distributed pr',
#  'undell and the\r\nonline distributed proof',
#  'ell and the\r\nonline distributed proofrea',
#  ' and the\r\nonline distributed proofreadin',
#  'd the\r\nonline distributed proofreading t',
#  'he\r\nonline distributed proofreading team',
#  '\nonline distributed proofreading team at',
#  'line distributed proofreading team at ht',
#  'e distributed proofreading team at http:',
#  'istributed proofreading team at http://w',
#  'ributed proofreading team at http://www.',
#  'uted proofreading team at http://www.pgd',
#  'd proofreading team at http://www.pgdp.n',
#  'roofreading team at http://www.pgdp.net\r',
#  'freading team at http://www.pgdp.net\r\n\r\n',
#  'ading team at http://www.pgdp.net\r\n\r\n\r\n\r',
#  'ng team at http://www.pgdp.net\r\n\r\n\r\n\r\n\r\n',
#  'team at http://www.pgdp.net\r\n\r\n\r\n\r\n\r\n\r\n\r',
#  'm at http://www.pgdp.net\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n',
#  't http://www.pgdp.net\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r',
#  'ttp://www.pgdp.net\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n t',
#  '://www.pgdp.net\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n the ',
#  'www.pgdp.net\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n the ill',
#  '.pgdp.net\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n the illust',
#  'dp.net\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n the illustrat',
#  'net\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n the illustrated ',
#  '\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n the illustrated chi',
#  '\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n the illustrated childr',
#  "\r\n\r\n\r\n\r\n\r\n\r\n\r\n the illustrated children'",
#  "\n\r\n\r\n\r\n\r\n\r\n the illustrated children's l",
#  "\r\n\r\n\r\n\r\n the illustrated children's libr",
#  "\n\r\n\r\n the illustrated children's library",
#  "\r\n the illustrated children's library\r\n\r",
#  "the illustrated children's library\r\n\r\n\r\n",
#  " illustrated children's library\r\n\r\n\r\n   ",
#  "lustrated children's library\r\n\r\n\r\n      ",
#  "trated children's library\r\n\r\n\r\n         ",
#  "ted children's library\r\n\r\n\r\n         _tr",
#  " children's library\r\n\r\n\r\n         _treas",
#  "ildren's library\r\n\r\n\r\n         _treasure",
#  "ren's library\r\n\r\n\r\n         _treasure is",
#  "'s library\r\n\r\n\r\n         _treasure islan",
#  'library\r\n\r\n\r\n         _treasure island_\r',
#  'rary\r\n\r\n\r\n         _treasure island_\r\n\r\n',
#  'y\r\n\r\n\r\n         _treasure island_\r\n\r\n   ',
#  '\r\n\r\n         _treasure island_\r\n\r\n      ',
#  '\n         _treasure island_\r\n\r\n       ro',
#  '       _treasure island_\r\n\r\n       rober',
#  '    _treasure island_\r\n\r\n       robert l',
#  ' _treasure island_\r\n\r\n       robert loui',
#  'reasure island_\r\n\r\n       robert louis s',
#  'sure island_\r\n\r\n       robert louis stev',
#  'e island_\r\n\r\n       robert louis stevens',
#  'sland_\r\n\r\n       robert louis stevenson\r',
#  'nd_\r\n\r\n       robert louis stevenson\r\n\r\n',
#  '\r\n\r\n       robert louis stevenson\r\n\r\n   ',
#  '\n       robert louis stevenson\r\n\r\n      ',
#  '     robert louis stevenson\r\n\r\n         ',
#  '  robert louis stevenson\r\n\r\n          _i',
#  'obert louis stevenson\r\n\r\n          _illu',
#  'rt louis stevenson\r\n\r\n          _illustr',
#  'louis stevenson\r\n\r\n          _illustrate',
#  'is stevenson\r\n\r\n          _illustrated b',
#  'stevenson\r\n\r\n          _illustrated by_\r',
#  'venson\r\n\r\n          _illustrated by_\r\n  ',
#  'son\r\n\r\n          _illustrated by_\r\n     ',
#  '\r\n\r\n          _illustrated by_\r\n        ',
#  '\n          _illustrated by_\r\n           ',
#  '        _illustrated by_\r\n            mi',
#  '     _illustrated by_\r\n            milo ',
#  '  _illustrated by_\r\n            milo win',
#  'illustrated by_\r\n            milo winter',
#  'ustrated by_\r\n            milo winter\r\n\r',
#  'rated by_\r\n            milo winter\r\n\r\n\r\n',
#  'ed by_\r\n            milo winter\r\n\r\n\r\n   ',
#  'by_\r\n            milo winter\r\n\r\n\r\n      ',
#  '\r\n            milo winter\r\n\r\n\r\n         ',
#  '           milo winter\r\n\r\n\r\n           [',
#  '        milo winter\r\n\r\n\r\n           [ill',
#  '     milo winter\r\n\r\n\r\n           [illust',
#  '  milo winter\r\n\r\n\r\n           [illustrat',
#  'ilo winter\r\n\r\n\r\n           [illustration',
#  ' winter\r\n\r\n\r\n           [illustration]\r\n',
#  'nter\r\n\r\n\r\n           [illustration]\r\n\r\n\r',
#  'r\r\n\r\n\r\n           [illustration]\r\n\r\n\r\n  ',
#  '\r\n\r\n           [illustration]\r\n\r\n\r\n     ',
#  '\n           [illustration]\r\n\r\n\r\n        ',
#  '         [illustration]\r\n\r\n\r\n           ',
#  '      [illustration]\r\n\r\n\r\n           gra',
#  '   [illustration]\r\n\r\n\r\n           gramer',
#  '[illustration]\r\n\r\n\r\n           gramercy ',
#  'lustration]\r\n\r\n\r\n           gramercy boo',
#  'tration]\r\n\r\n\r\n           gramercy books\r',
#  'tion]\r\n\r\n\r\n           gramercy books\r\n  ',
#  'n]\r\n\r\n\r\n           gramercy books\r\n     ',
#  '\n\r\n\r\n           gramercy books\r\n        ',
#  '\r\n           gramercy books\r\n           ',
#  '          gramercy books\r\n              ',
#  '       gramercy books\r\n              new',
#  '    gramercy books\r\n              new yo',
#  ' gramercy books\r\n              new york\r',
#  'amercy books\r\n              new york\r\n\r\n',
#  'rcy books\r\n              new york\r\n\r\n\r\n\r',
#  ' books\r\n              new york\r\n\r\n\r\n\r\n\r\n',
#  'oks\r\n              new york\r\n\r\n\r\n\r\n\r\n fo',
#  '\r\n              new york\r\n\r\n\r\n\r\n\r\n forew',
#  '             new york\r\n\r\n\r\n\r\n\r\n foreword',
#  '          new york\r\n\r\n\r\n\r\n\r\n foreword co',
#  '       new york\r\n\r\n\r\n\r\n\r\n foreword copyr',
#  '    new york\r\n\r\n\r\n\r\n\r\n foreword copyrigh',
#  ' new york\r\n\r\n\r\n\r\n\r\n foreword copyright  ',
#  'w york\r\n\r\n\r\n\r\n\r\n foreword copyright  198',
#  'ork\r\n\r\n\r\n\r\n\r\n foreword copyright  1986 b',
#  '\r\n\r\n\r\n\r\n\r\n foreword copyright  1986 by r',
#  '\n\r\n\r\n\r\n foreword copyright  1986 by rand',
#  '\r\n\r\n foreword copyright  1986 by random ',
#  '\n foreword copyright  1986 by random hou',
#  'oreword copyright  1986 by random house ',
#  'word copyright  1986 by random house val',
#  'd copyright  1986 by random house value ',
#  'opyright  1986 by random house value pub',
#  'right  1986 by random house value publis',
#  'ht  1986 by random house value publishin',
#  ' 1986 by random house value publishing\r\n',
#  '86 by random house value publishing\r\n co',
#  'by random house value publishing\r\n color',
#  'random house value publishing\r\n color il',
#  'dom house value publishing\r\n color illus',
#  ' house value publishing\r\n color illustra',
#  'use value publishing\r\n color illustratio',
#  ' value publishing\r\n color illustrations ',
#  'lue publishing\r\n color illustrations by ',
#  ' publishing\r\n color illustrations by mil',
#  'blishing\r\n color illustrations by milo w',
#  'shing\r\n color illustrations by milo wint',
#  'ng\r\n color illustrations by milo winter ',
#  '\n color illustrations by milo winter cop',
#  'olor illustrations by milo winter copyri',
#  'r illustrations by milo winter copyright',
#  'llustrations by milo winter copyright  1',
#  'strations by milo winter copyright  1915',
#  'ations by milo winter copyright  1915, 1',
#  'ons by milo winter copyright  1915, 1943',
#  ' by milo winter copyright  1915, 1943 by',
#  ' milo winter copyright  1915, 1943 by ra',
#  'lo winter copyright  1915, 1943 by rand\r',
#  'winter copyright  1915, 1943 by rand\r\n m',
#  'ter copyright  1915, 1943 by rand\r\n mcna',
#  ' copyright  1915, 1943 by rand\r\n mcnally',
#  'pyright  1915, 1943 by rand\r\n mcnally & ',
#  'ight  1915, 1943 by rand\r\n mcnally & com',
#  't  1915, 1943 by rand\r\n mcnally & compan',
#  '1915, 1943 by rand\r\n mcnally & company\r\n',
#  '5, 1943 by rand\r\n mcnally & company\r\n al',
#  '1943 by rand\r\n mcnally & company\r\n all r',
#  '3 by rand\r\n mcnally & company\r\n all righ',
#  'y rand\r\n mcnally & company\r\n all rights ',
#  'and\r\n mcnally & company\r\n all rights res',
#  '\r\n mcnally & company\r\n all rights reserv',
#  'mcnally & company\r\n all rights reserved.',
#  'ally & company\r\n all rights reserved.\r\n\r',
#  'y & company\r\n all rights reserved.\r\n\r\n t',
#  ' company\r\n all rights reserved.\r\n\r\n this',
#  'mpany\r\n all rights reserved.\r\n\r\n this 20',
#  'ny\r\n all rights reserved.\r\n\r\n this 2002 ',
#  '\n all rights reserved.\r\n\r\n this 2002 edi',
#  'll rights reserved.\r\n\r\n this 2002 editio',
#  'rights reserved.\r\n\r\n this 2002 edition p',
#  'hts reserved.\r\n\r\n this 2002 edition publ',
#  ' reserved.\r\n\r\n this 2002 edition publish',
#  'served.\r\n\r\n this 2002 edition published ',
#  'ved.\r\n\r\n this 2002 edition published by ',
#  '.\r\n\r\n this 2002 edition published by gra',
#  '\r\n this 2002 edition published by gramer',
#  'this 2002 edition published by gramercy ',
#  's 2002 edition published by gramercy boo',
#  '002 edition published by gramercy books,',
#  ' edition published by gramercy books, an',
#  'ition published by gramercy books, an im',
#  'on published by gramercy books, an impri',
#  'published by gramercy books, an imprint ',
#  'lished by gramercy books, an imprint of ',
#  'hed by gramercy books, an imprint of ran',
#  ' by gramercy books, an imprint of random',
#  ' gramercy books, an imprint of random\r\n ',
#  'amercy books, an imprint of random\r\n hou',
#  'rcy books, an imprint of random\r\n house ',
#  ' books, an imprint of random\r\n house val',
#  'oks, an imprint of random\r\n house value ',
#  ', an imprint of random\r\n house value pub',
#  'n imprint of random\r\n house value publis',
#  'mprint of random\r\n house value publishin',
#  'int of random\r\n house value publishing, ',
#  ' of random\r\n house value publishing, a d',
#  ' random\r\n house value publishing, a divi',
#  'ndom\r\n house value publishing, a divisio',
#  'm\r\n house value publishing, a division o',
#  ' house value publishing, a division of r',
#  'use value publishing, a division of rand',
#  ' value publishing, a division of random ',
#  'lue publishing, a division of random hou',
#  ' publishing, a division of random house,',
#  'blishing, a division of random house, in',
#  'shing, a division of random house, inc.,',
#  'ng, a division of random house, inc., 28',
#  ' a division of random house, inc., 280 p',
#  'division of random house, inc., 280 park',
#  'ision of random house, inc., 280 park\r\n ',
#  'on of random house, inc., 280 park\r\n ave',
#  'of random house, inc., 280 park\r\n avenue',
#  'random house, inc., 280 park\r\n avenue, n',
#  'dom house, inc., 280 park\r\n avenue, new ',
#  ' house, inc., 280 park\r\n avenue, new yor',
#  'use, inc., 280 park\r\n avenue, new york, ',
#  ', inc., 280 park\r\n avenue, new york, ny ',
#  'nc., 280 park\r\n avenue, new york, ny 100',
#  ', 280 park\r\n avenue, new york, ny 10017.',
#  '80 park\r\n avenue, new york, ny 10017.\r\n\r',
#  'park\r\n avenue, new york, ny 10017.\r\n\r\n g',
#  'k\r\n avenue, new york, ny 10017.\r\n\r\n gram',
#  ' avenue, new york, ny 10017.\r\n\r\n gramerc',
#  'enue, new york, ny 10017.\r\n\r\n gramercy i',
#  'e, new york, ny 10017.\r\n\r\n gramercy is a',
#  'new york, ny 10017.\r\n\r\n gramercy is a re',
#  ' york, ny 10017.\r\n\r\n gramercy is a regis',
#  'rk, ny 10017.\r\n\r\n gramercy is a register',
#  ' ny 10017.\r\n\r\n gramercy is a registered ',
#  ' 10017.\r\n\r\n gramercy is a registered tra',
#  '017.\r\n\r\n gramercy is a registered tradem',
#  '.\r\n\r\n gramercy is a registered trademark',
#  '\r\n gramercy is a registered trademark an',
#  'gramercy is a registered trademark and t',
#  'mercy is a registered trademark and the ',
#  'cy is a registered trademark and the col',
#  'is a registered trademark and the coloph',
#  'a registered trademark and the colophon ',
#  'egistered trademark and the colophon is ',
#  'stered trademark and the colophon is a t',
#  'red trademark and the colophon is a trad',
#  ' trademark and the colophon is a tradema',
#  'ademark and the colophon is a trademark ',
#  'mark and the colophon is a trademark of\r',
#  'k and the colophon is a trademark of\r\n r',
#  'nd the colophon is a trademark of\r\n rand',
#  'the colophon is a trademark of\r\n random ',
#  ' colophon is a trademark of\r\n random hou',
#  'lophon is a trademark of\r\n random house,',
#  'hon is a trademark of\r\n random house, in',
#  ' is a trademark of\r\n random house, inc.\r',
#  ' a trademark of\r\n random house, inc.\r\n\r\n',
#  'trademark of\r\n random house, inc.\r\n\r\n pr',
#  'demark of\r\n random house, inc.\r\n\r\n print',
#  'ark of\r\n random house, inc.\r\n\r\n printed ',
#  ' of\r\n random house, inc.\r\n\r\n printed and',
#  '\r\n random house, inc.\r\n\r\n printed and bo',
#  'random house, inc.\r\n\r\n printed and bound',
#  'dom house, inc.\r\n\r\n printed and bound in',
#  ' house, inc.\r\n\r\n printed and bound in th',
#  'use, inc.\r\n\r\n printed and bound in the u',
#  ', inc.\r\n\r\n printed and bound in the unit',
#  'nc.\r\n\r\n printed and bound in the united ',
#  '\r\n\r\n printed and bound in the united sta',
#  '\n printed and bound in the united states',
#  'rinted and bound in the united states of',
#  'ted and bound in the united states of am',
#  ' and bound in the united states of ameri',
#  'd bound in the united states of america\r',
#  'ound in the united states of america\r\n\r\n',
#  'd in the united states of america\r\n\r\n co',
#  'n the united states of america\r\n\r\n cover',
#  'he united states of america\r\n\r\n cover de',
#  'united states of america\r\n\r\n cover desig',
#  'ted states of america\r\n\r\n cover design b',
#  ' states of america\r\n\r\n cover design by j',
#  'ates of america\r\n\r\n cover design by judy',
#  's of america\r\n\r\n cover design by judy fu',
#  'f america\r\n\r\n cover design by judy fucci',
#  'merica\r\n\r\n cover design by judy fucci, s',
#  'ica\r\n\r\n cover design by judy fucci, stud',
#  '\r\n\r\n cover design by judy fucci, studio ',
#  '\n cover design by judy fucci, studio gra',
#  'over design by judy fucci, studio graphi',
#  'r design by judy fucci, studio graphix, ',
#  'esign by judy fucci, studio graphix, inc',
#  'gn by judy fucci, studio graphix, inc.\r\n',
#  'by judy fucci, studio graphix, inc.\r\n\r\n ',
#  'judy fucci, studio graphix, inc.\r\n\r\n ran',
#  'y fucci, studio graphix, inc.\r\n\r\n random',
#  'ucci, studio graphix, inc.\r\n\r\n random ho',
#  'i, studio graphix, inc.\r\n\r\n random house',
#  'studio graphix, inc.\r\n\r\n random house\r\n ',
#  'dio graphix, inc.\r\n\r\n random house\r\n new',
#  ' graphix, inc.\r\n\r\n random house\r\n new yo',
#  'aphix, inc.\r\n\r\n random house\r\n new york ',
#  'ix, inc.\r\n\r\n random house\r\n new york  to',
#  ' inc.\r\n\r\n random house\r\n new york  toron',
#  'c.\r\n\r\n random house\r\n new york  toronto ',
#  '\n\r\n random house\r\n new york  toronto  lo',
#  ' random house\r\n new york  toronto  londo',
#  'ndom house\r\n new york  toronto  london  ',
#  'm house\r\n new york  toronto  london  syd',
#  'ouse\r\n new york  toronto  london  sydney',
#  'e\r\n new york  toronto  london  sydney  a',
#  ' new york  toronto  london  sydney  auck',
#  'w york  toronto  london  sydney  aucklan',
#  'ork  toronto  london  sydney  auckland\r\n',
#  '  toronto  london  sydney  auckland\r\n ww',
#  'oronto  london  sydney  auckland\r\n www.r',
#  'nto  london  sydney  auckland\r\n www.rand',
#  '  london  sydney  auckland\r\n www.randomh',
#  'ondon  sydney  auckland\r\n www.randomhous',
#  'on  sydney  auckland\r\n www.randomhouse.c',
#  ' sydney  auckland\r\n www.randomhouse.com\r',
#  'dney  auckland\r\n www.randomhouse.com\r\n\r\n',
#  'y  auckland\r\n www.randomhouse.com\r\n\r\n\r\n ',
#  'auckland\r\n www.randomhouse.com\r\n\r\n\r\n lib',
#  'kland\r\n www.randomhouse.com\r\n\r\n\r\n librar',
#  'nd\r\n www.randomhouse.com\r\n\r\n\r\n library o',
#  '\n www.randomhouse.com\r\n\r\n\r\n library of c',
#  'ww.randomhouse.com\r\n\r\n\r\n library of cong',
#  'randomhouse.com\r\n\r\n\r\n library of congres',
#  'domhouse.com\r\n\r\n\r\n library of congress c',
#  'house.com\r\n\r\n\r\n library of congress cata',
#  'se.com\r\n\r\n\r\n library of congress catalog',
#  'com\r\n\r\n\r\n library of congress cataloging',
#  '\r\n\r\n\r\n library of congress cataloging-in',
#  '\n\r\n library of congress cataloging-in-pu',
#  ' library of congress cataloging-in-publi',
#  'brary of congress cataloging-in-publicat',
#  'ry of congress cataloging-in-publication',
#  'of congress cataloging-in-publication da',
#  'congress cataloging-in-publication data\r',
#  'gress cataloging-in-publication data\r\n\r\n',
#  'ss cataloging-in-publication data\r\n\r\n st',
#  'cataloging-in-publication data\r\n\r\n steve',
#  'aloging-in-publication data\r\n\r\n stevenso',
#  'ging-in-publication data\r\n\r\n stevenson, ',
#  'g-in-publication data\r\n\r\n stevenson, rob',
#  'n-publication data\r\n\r\n stevenson, robert',
#  'ublication data\r\n\r\n stevenson, robert lo',
#  'ication data\r\n\r\n stevenson, robert louis',
#  'tion data\r\n\r\n stevenson, robert louis, 1',
#  'n data\r\n\r\n stevenson, robert louis, 1850',
#  'ata\r\n\r\n stevenson, robert louis, 1850-18',
#  '\r\n\r\n stevenson, robert louis, 1850-1894.',
#  '\n stevenson, robert louis, 1850-1894.\r\n ',
#  'tevenson, robert louis, 1850-1894.\r\n    ',
#  'enson, robert louis, 1850-1894.\r\n     tr',
#  'on, robert louis, 1850-1894.\r\n     treas',
#  ' robert louis, 1850-1894.\r\n     treasure',
#  'bert louis, 1850-1894.\r\n     treasure is',
#  't louis, 1850-1894.\r\n     treasure islan',
#  'ouis, 1850-1894.\r\n     treasure island/r',
#  's, 1850-1894.\r\n     treasure island/robe',
#  '1850-1894.\r\n     treasure island/robert ',
#  '0-1894.\r\n     treasure island/robert lou',
#  '894.\r\n     treasure island/robert louis ',
#  '.\r\n     treasure island/robert louis ste',
#  '     treasure island/robert louis steven',
#  '  treasure island/robert louis stevenson',
#  'reasure island/robert louis stevenson; i',
#  'sure island/robert louis stevenson; illu',
#  'e island/robert louis stevenson; illustr',
#  'sland/robert louis stevenson; illustrate',
#  'nd/robert louis stevenson; illustrated i',
#  'robert louis stevenson; illustrated in c',
#  'ert louis stevenson; illustrated in colo',
#  ' louis stevenson; illustrated in color b',
#  'uis stevenson; illustrated in color by\r\n',
#  ' stevenson; illustrated in color by\r\n   ',
#  'evenson; illustrated in color by\r\n   mil',
#  'nson; illustrated in color by\r\n   milo w',
#  'n; illustrated in color by\r\n   milo wint',
#  'illustrated in color by\r\n   milo winter.',
#  'ustrated in color by\r\n   milo winter.\r\n ',
#  'rated in color by\r\n   milo winter.\r\n    ',
#  'ed in color by\r\n   milo winter.\r\n       ',
#  'in color by\r\n   milo winter.\r\n       p. ',
#  'color by\r\n   milo winter.\r\n       p. cm.',
#  'or by\r\n   milo winter.\r\n       p. cm.--(',
#  'by\r\n   milo winter.\r\n       p. cm.--(ill',
#  '\n   milo winter.\r\n       p. cm.--(illust',
#  ' milo winter.\r\n       p. cm.--(illustrat',
#  'lo winter.\r\n       p. cm.--(illustrated ',
#  'winter.\r\n       p. cm.--(illustrated chi',
#  'ter.\r\n       p. cm.--(illustrated childr',
#  ".\r\n       p. cm.--(illustrated children'",
#  "       p. cm.--(illustrated children's l",
#  "    p. cm.--(illustrated children's libr",
#  " p. cm.--(illustrated children's library",
#  " cm.--(illustrated children's library)\r\n",
#  ".--(illustrated children's library)\r\n   ",
#  "(illustrated children's library)\r\n     o",
#  "lustrated children's library)\r\n     orig",
#  "trated children's library)\r\n     origina",
#  "ted children's library)\r\n     originally",
#  " children's library)\r\n     originally pu",
#  "ildren's library)\r\n     originally publi",
#  "ren's library)\r\n     originally publishe",
#  "'s library)\r\n     originally published: ",
#  'library)\r\n     originally published: new',
#  'rary)\r\n     originally published: new yo',
#  'y)\r\n     originally published: new york:',
#  '\n     originally published: new york: ch',
#  '   originally published: new york: child',
#  'originally published: new york: children',
#  "ginally published: new york: children's ",
#  "ally published: new york: children's cla",
#  "y published: new york: children's classi",
#  "ublished: new york: children's classics,",
#  "ished: new york: children's classics, 19",
#  "ed: new york: children's classics, 1986.",
#  " new york: children's classics, 1986.\r\n ",
#  "w york: children's classics, 1986.\r\n    ",
#  "ork: children's classics, 1986.\r\n     su",
#  ": children's classics, 1986.\r\n     summa",
#  "hildren's classics, 1986.\r\n     summary:",
#  "dren's classics, 1986.\r\n     summary: wh",
#  "n's classics, 1986.\r\n     summary: while",
#  ' classics, 1986.\r\n     summary: while go',
#  'assics, 1986.\r\n     summary: while going',
#  'ics, 1986.\r\n     summary: while going th',
#  ', 1986.\r\n     summary: while going throu',
#  '986.\r\n     summary: while going through ',
#  '.\r\n     summary: while going through the',
#  '     summary: while going through the po',
#  '  summary: while going through the posse',
#  'ummary: while going through the possessi',
#  'ary: while going through the possessions',
#  ': while going through the possessions of',
#  'hile going through the possessions of a ',
#  'e going through the possessions of a dec',
#  'oing through the possessions of a deceas',
#  'g through the possessions of a deceased ',
#  'hrough the possessions of a deceased gue',
#  'ugh the possessions of a deceased guest\r',
#  ' the possessions of a deceased guest\r\n  ',
#  'e possessions of a deceased guest\r\n   wh',
#  'ossessions of a deceased guest\r\n   who o',
#  'essions of a deceased guest\r\n   who owed',
#  'ions of a deceased guest\r\n   who owed th',
#  's of a deceased guest\r\n   who owed them ',
#  'f a deceased guest\r\n   who owed them mon',
#  ' deceased guest\r\n   who owed them money,',
#  'ceased guest\r\n   who owed them money, th',
#  'sed guest\r\n   who owed them money, the m',
#  ' guest\r\n   who owed them money, the mist',
#  'est\r\n   who owed them money, the mistres',
#  '\r\n   who owed them money, the mistress o',
#  '  who owed them money, the mistress of t',
#  'ho owed them money, the mistress of the ',
#  'owed them money, the mistress of the inn',
#  'd them money, the mistress of the inn an',
#  'hem money, the mistress of the inn and h',
#  ' money, the mistress of the inn and her ',
#  'ney, the mistress of the inn and her son',
#  ', the mistress of the inn and her son fi',
#  'he mistress of the inn and her son find ',
#  'mistress of the inn and her son find a\r\n',
#  'tress of the inn and her son find a\r\n   ',
#  'ss of the inn and her son find a\r\n   tre',
#  'of the inn and her son find a\r\n   treasu',
#  'the inn and her son find a\r\n   treasure ',
#  ' inn and her son find a\r\n   treasure map',
#  'n and her son find a\r\n   treasure map th',
#  'nd her son find a\r\n   treasure map that ',
#  'her son find a\r\n   treasure map that lea',
#  ' son find a\r\n   treasure map that leads ',
#  'n find a\r\n   treasure map that leads the',
#  'ind a\r\n   treasure map that leads them t',
#  ' a\r\n   treasure map that leads them to a',
#  '\n   treasure map that leads them to a pi',
#  ' treasure map that leads them to a pirat',
#  "easure map that leads them to a pirate's",
#  "ure map that leads them to a pirate's fo",
#  " map that leads them to a pirate's fortu",
#  "p that leads them to a pirate's fortune.",
#  "hat leads them to a pirate's fortune.\r\n ",
#  " leads them to a pirate's fortune.\r\n    ",
#  "ads them to a pirate's fortune.\r\n     is",
#  " them to a pirate's fortune.\r\n     isbn ",
#  "em to a pirate's fortune.\r\n     isbn 0-5",
#  "to a pirate's fortune.\r\n     isbn 0-517-",
#  "a pirate's fortune.\r\n     isbn 0-517-221",
#  "irate's fortune.\r\n     isbn 0-517-22114-",
#  "te's fortune.\r\n     isbn 0-517-22114-4\r\n",
#  's fortune.\r\n     isbn 0-517-22114-4\r\n   ',
#  'ortune.\r\n     isbn 0-517-22114-4\r\n     [',
#  'une.\r\n     isbn 0-517-22114-4\r\n     [1. ',
#  '.\r\n     isbn 0-517-22114-4\r\n     [1. bur',
#  '     isbn 0-517-22114-4\r\n     [1. buried',
#  '  isbn 0-517-22114-4\r\n     [1. buried tr',
#  'sbn 0-517-22114-4\r\n     [1. buried treas',
#  ' 0-517-22114-4\r\n     [1. buried treasure',
#  '517-22114-4\r\n     [1. buried treasure--f',
#  '-22114-4\r\n     [1. buried treasure--fict',
#  '114-4\r\n     [1. buried treasure--fiction',
#  '-4\r\n     [1. buried treasure--fiction. 2',
#  '\n     [1. buried treasure--fiction. 2. p',
#  '   [1. buried treasure--fiction. 2. pira',
#  '[1. buried treasure--fiction. 2. pirates',
#  ' buried treasure--fiction. 2. pirates--f',
#  'ried treasure--fiction. 2. pirates--fict',
#  'd treasure--fiction. 2. pirates--fiction',
#  'reasure--fiction. 2. pirates--fiction. 3',
#  'sure--fiction. 2. pirates--fiction. 3. a',
#  'e--fiction. 2. pirates--fiction. 3. adve',
#  'fiction. 2. pirates--fiction. 3. adventu',
#  'tion. 2. pirates--fiction. 3. adventure\r',
#  'n. 2. pirates--fiction. 3. adventure\r\n  ',
#  '2. pirates--fiction. 3. adventure\r\n   an',
#  'pirates--fiction. 3. adventure\r\n   and a',
#  'ates--fiction. 3. adventure\r\n   and adve',
#  's--fiction. 3. adventure\r\n   and adventu',
#  'fiction. 3. adventure\r\n   and adventures',
#  'tion. 3. adventure\r\n   and adventures--f',
#  'n. 3. adventure\r\n   and adventures--fict',
#  '3. adventure\r\n   and adventures--fiction',
#  'adventure\r\n   and adventures--fiction. 4',
#  'enture\r\n   and adventures--fiction. 4. c',
#  'ure\r\n   and adventures--fiction. 4. cari',
#  '\r\n   and adventures--fiction. 4. caribbe',
#  '  and adventures--fiction. 4. caribbean ',
#  'nd adventures--fiction. 4. caribbean are',
#  'adventures--fiction. 4. caribbean area--',
#  'entures--fiction. 4. caribbean area--his',
#  'ures--fiction. 4. caribbean area--histor',
#  's--fiction. 4. caribbean area--history--',
#  'fiction. 4. caribbean area--history--18t',
#  'tion. 4. caribbean area--history--18th\r\n',
#  'n. 4. caribbean area--history--18th\r\n   ',
#  '4. caribbean area--history--18th\r\n   cen',
#  'caribbean area--history--18th\r\n   centur',
#  'ibbean area--history--18th\r\n   century--',
#  'ean area--history--18th\r\n   century--fic',
#  ' area--history--18th\r\n   century--fictio',
#  'ea--history--18th\r\n   century--fiction.]',
#  '-history--18th\r\n   century--fiction.] i.',
#  'story--18th\r\n   century--fiction.] i. wi',
#  'ry--18th\r\n   century--fiction.] i. winte',
#  '-18th\r\n   century--fiction.] i. winter, ',
#  'th\r\n   century--fiction.] i. winter, mil',
#  '\n   century--fiction.] i. winter, milo, ',
#  ' century--fiction.] i. winter, milo, 188',
#  'ntury--fiction.] i. winter, milo, 1888-1',
#  'ry--fiction.] i. winter, milo, 1888-1956',
#  '-fiction.] i. winter, milo, 1888-1956, i',
#  'ction.] i. winter, milo, 1888-1956, ill.',
#  'on.] i. winter, milo, 1888-1956, ill. ii',
#  '] i. winter, milo, 1888-1956, ill. ii. t',
#  '. winter, milo, 1888-1956, ill. ii. titl',
#  'inter, milo, 1888-1956, ill. ii. title.\r',
#  'er, milo, 1888-1956, ill. ii. title.\r\n  ',
#  ' milo, 1888-1956, ill. ii. title.\r\n   ii',
#  'lo, 1888-1956, ill. ii. title.\r\n   iii. ',
#  ' 1888-1956, ill. ii. title.\r\n   iii. ser',
#  '88-1956, ill. ii. title.\r\n   iii. series',
#  '1956, ill. ii. title.\r\n   iii. series.\r\n',
#  '6, ill. ii. title.\r\n   iii. series.\r\n\r\n ',
#  'ill. ii. title.\r\n   iii. series.\r\n\r\n   p',
#  '. ii. title.\r\n   iii. series.\r\n\r\n   pz7.',
#  'i. title.\r\n   iii. series.\r\n\r\n   pz7.s84',
#  'title.\r\n   iii. series.\r\n\r\n   pz7.s8482 ',
#  'le.\r\n   iii. series.\r\n\r\n   pz7.s8482 tr ',
#  '\r\n   iii. series.\r\n\r\n   pz7.s8482 tr 200',
#  '  iii. series.\r\n\r\n   pz7.s8482 tr 2002\r\n',
#  'ii. series.\r\n\r\n   pz7.s8482 tr 2002\r\n   ',
#  ' series.\r\n\r\n   pz7.s8482 tr 2002\r\n   [fi',
#  'ries.\r\n\r\n   pz7.s8482 tr 2002\r\n   [fic]-',
#  's.\r\n\r\n   pz7.s8482 tr 2002\r\n   [fic]--dc',
#  '\n\r\n   pz7.s8482 tr 2002\r\n   [fic]--dc21\r',
#  '   pz7.s8482 tr 2002\r\n   [fic]--dc21\r\n\r\n',
#  'pz7.s8482 tr 2002\r\n   [fic]--dc21\r\n\r\n   ',
#  '.s8482 tr 2002\r\n   [fic]--dc21\r\n\r\n      ',
#  '482 tr 2002\r\n   [fic]--dc21\r\n\r\n         ',
#  ' tr 2002\r\n   [fic]--dc21\r\n\r\n            ',
#  ' 2002\r\n   [fic]--dc21\r\n\r\n               ',
#  '02\r\n   [fic]--dc21\r\n\r\n                  ',
#  '\n   [fic]--dc21\r\n\r\n                     ',
#  ' [fic]--dc21\r\n\r\n                        ',
#  'ic]--dc21\r\n\r\n                           ',
#  '--dc21\r\n\r\n                              ',
#  'c21\r\n\r\n                                 ',
#  '\r\n\r\n                                    ',
#  '\n                                       ',
#  '                                        ',
#  '                                        ',
#  '                                        ',
#  '                                        ',
#  '                                        ',
#  '                                        ',
#  '                                        ',
#  '                                       2',
#  '                                    2002',
#  '                                 2002023',
#  '                              2002023301',
#  '                           2002023301\r\n ',
#  '                        2002023301\r\n 9 8',
#  '                     2002023301\r\n 9 8 7 ',
#  '                  2002023301\r\n 9 8 7 6 5',
#  '               2002023301\r\n 9 8 7 6 5 4 ',
#  '            2002023301\r\n 9 8 7 6 5 4 3 2',
#  '         2002023301\r\n 9 8 7 6 5 4 3 2 1\r',
#  '      2002023301\r\n 9 8 7 6 5 4 3 2 1\r\n\r\n',
#  '   2002023301\r\n 9 8 7 6 5 4 3 2 1\r\n\r\n\r\nt',
#  '2002023301\r\n 9 8 7 6 5 4 3 2 1\r\n\r\n\r\ntran',
#  '2023301\r\n 9 8 7 6 5 4 3 2 1\r\n\r\n\r\ntranscr',
#  '3301\r\n 9 8 7 6 5 4 3 2 1\r\n\r\n\r\ntranscribe',
#  "1\r\n 9 8 7 6 5 4 3 2 1\r\n\r\n\r\ntranscriber's",
#  " 9 8 7 6 5 4 3 2 1\r\n\r\n\r\ntranscriber's no",
#  "8 7 6 5 4 3 2 1\r\n\r\n\r\ntranscriber's note:",
#  " 6 5 4 3 2 1\r\n\r\n\r\ntranscriber's note:\r\n\r",
#  "5 4 3 2 1\r\n\r\n\r\ntranscriber's note:\r\n\r\n  ",
#  " 3 2 1\r\n\r\n\r\ntranscriber's note:\r\n\r\n    m",
#  "2 1\r\n\r\n\r\ntranscriber's note:\r\n\r\n    mino",
#  "\r\n\r\n\r\ntranscriber's note:\r\n\r\n    minor s",
#  "\n\r\ntranscriber's note:\r\n\r\n    minor spel",
#  "transcriber's note:\r\n\r\n    minor spellin",
#  "nscriber's note:\r\n\r\n    minor spelling a",
#  "riber's note:\r\n\r\n    minor spelling and ",
#  "er's note:\r\n\r\n    minor spelling and typ",
#  's note:\r\n\r\n    minor spelling and typogr',
#  'ote:\r\n\r\n    minor spelling and typograph',
#  ':\r\n\r\n    minor spelling and typographica',
#  '\r\n    minor spelling and typographical e',
#  '   minor spelling and typographical erro',
#  'minor spelling and typographical errors ',
#  'or spelling and typographical errors hav',
#  'spelling and typographical errors have b',
#  'lling and typographical errors have been',
#  'ng and typographical errors have been co',
#  'and typographical errors have been corre',
#  ' typographical errors have been correcte',
#  'pographical errors have been corrected w',
#  'raphical errors have been corrected with',
#  'hical errors have been corrected without',
#  'al errors have been corrected without\r\n ',
#  'errors have been corrected without\r\n    ',
#  'ors have been corrected without\r\n    not',
#  ' have been corrected without\r\n    note. ',
#  've been corrected without\r\n    note. dia',
#  'been corrected without\r\n    note. dialec',
#  'n corrected without\r\n    note. dialect a',
#  'orrected without\r\n    note. dialect and ',
#  'ected without\r\n    note. dialect and var',
#  'ed without\r\n    note. dialect and varian',
#  'without\r\n    note. dialect and variant s',
#  'hout\r\n    note. dialect and variant spel',
#  't\r\n    note. dialect and variant spellin',
#  '    note. dialect and variant spellings ',
#  ' note. dialect and variant spellings hav',
#  'te. dialect and variant spellings have b',
#  ' dialect and variant spellings have been',
#  'alect and variant spellings have been re',
#  'ct and variant spellings have been retai',
#  'and variant spellings have been retained',
#  ' variant spellings have been retained, w',
#  'riant spellings have been retained, whil',
#  'nt spellings have been retained, whilst\r',
#  'spellings have been retained, whilst\r\n  ',
#  'llings have been retained, whilst\r\n    i',
#  'ngs have been retained, whilst\r\n    inco',
#  ' have been retained, whilst\r\n    inconsi',
#  've been retained, whilst\r\n    inconsiste',
#  'been retained, whilst\r\n    inconsistent ',
#  'n retained, whilst\r\n    inconsistent hyp',
#  'etained, whilst\r\n    inconsistent hyphen',
#  'ined, whilst\r\n    inconsistent hyphenati',
#  'd, whilst\r\n    inconsistent hyphenation ',
#  'whilst\r\n    inconsistent hyphenation has',
#  'lst\r\n    inconsistent hyphenation has be',
#  '\r\n    inconsistent hyphenation has been ',
#  '   inconsistent hyphenation has been sta',
#  'inconsistent hyphenation has been standa',
#  'onsistent hyphenation has been standardi',
#  'istent hyphenation has been standardised',
#  'ent hyphenation has been standardised. c',
#  ' hyphenation has been standardised. colo',
#  'phenation has been standardised. color p',
#  'nation has been standardised. color plat',
#  'ion has been standardised. color plates ',
#  ' has been standardised. color plates hav',
#  's been standardised. color plates have\r\n',
#  'een standardised. color plates have\r\n   ',
#  ' standardised. color plates have\r\n    be',
#  'andardised. color plates have\r\n    been ',
#  'ardised. color plates have\r\n    been rep',
#  'ised. color plates have\r\n    been reposi',
#  'd. color plates have\r\n    been repositio',
#  'color plates have\r\n    been repositioned',
#  'or plates have\r\n    been repositioned ac',
#  'plates have\r\n    been repositioned accor',
#  'tes have\r\n    been repositioned accordin',
#  ' have\r\n    been repositioned according t',
#  've\r\n    been repositioned according to t',
#  '\n    been repositioned according to thei',
#  '  been repositioned according to their c',
#  'een repositioned according to their capt',
#  ' repositioned according to their caption',
#  'positioned according to their captions; ',
#  'itioned according to their captions; the',
#  "oned according to their captions; the 'c",
#  "d according to their captions; the 'colo",
#  "ccording to their captions; the 'color p",
#  "rding to their captions; the 'color plat",
#  "ng to their captions; the 'color plates'",
#  "to their captions; the 'color plates'\r\n ",
#  "their captions; the 'color plates'\r\n    ",
#  "ir captions; the 'color plates'\r\n    lis",
#  "captions; the 'color plates'\r\n    listin",
#  "tions; the 'color plates'\r\n    listing r",
#  "ns; the 'color plates'\r\n    listing rema",
#  " the 'color plates'\r\n    listing remains",
#  "e 'color plates'\r\n    listing remains as",
#  "color plates'\r\n    listing remains as pr",
#  "or plates'\r\n    listing remains as print",
#  "plates'\r\n    listing remains as printed ",
#  "tes'\r\n    listing remains as printed to ",
#  "'\r\n    listing remains as printed to ind",
#  '    listing remains as printed to indica',
#  ' listing remains as printed to indicate ',
#  'sting remains as printed to indicate the',
#  'ng remains as printed to indicate the or',
#  'remains as printed to indicate the origi',
#  'ains as printed to indicate the original',
#  's as printed to indicate the original lo',
#  's printed to indicate the original locat',
#  'rinted to indicate the original location',
#  'ted to indicate the original locations.\r',
#  ' to indicate the original locations.\r\n\r\n',
#  ' indicate the original locations.\r\n\r\n\r\n\r',
#  'dicate the original locations.\r\n\r\n\r\n\r\n\r\n',
#  'ate the original locations.\r\n\r\n\r\n\r\n\r\ncon',
#  ' the original locations.\r\n\r\n\r\n\r\n\r\nconten',
#  'e original locations.\r\n\r\n\r\n\r\n\r\ncontents\r',
#  'riginal locations.\r\n\r\n\r\n\r\n\r\ncontents\r\n\r\n',
#  'inal locations.\r\n\r\n\r\n\r\n\r\ncontents\r\n\r\n\r\n ',
#  'l locations.\r\n\r\n\r\n\r\n\r\ncontents\r\n\r\n\r\n    ',
#  'ocations.\r\n\r\n\r\n\r\n\r\ncontents\r\n\r\n\r\n       ',
#  'tions.\r\n\r\n\r\n\r\n\r\ncontents\r\n\r\n\r\n          ',
#  'ns.\r\n\r\n\r\n\r\n\r\ncontents\r\n\r\n\r\n             ',
#  '\r\n\r\n\r\n\r\n\r\ncontents\r\n\r\n\r\n                ',
#  '\n\r\n\r\n\r\ncontents\r\n\r\n\r\n                   ',
#  '\r\n\r\ncontents\r\n\r\n\r\n                      ',
#  '\ncontents\r\n\r\n\r\n                         ',
#  'ntents\r\n\r\n\r\n                            ',
#  'nts\r\n\r\n\r\n                               ',
#  '\r\n\r\n\r\n                                  ',
#  '\n\r\n                                     ',
#  '                                        ',
#  '                                        ',
#  '                                        ',
#  '                                        ',
#  '                                        ',
#  '                                        ',
#  '                                        ',
#  '                                        ',
#  '                                     pag',
#  '                                  page\r\n',
#  '                               page\r\n _t',
#  '                            page\r\n _to t',
#  '                         page\r\n _to the ',
#  '                      page\r\n _to the hes',
#  '                   page\r\n _to the hesita',
#  '                page\r\n _to the hesitatin',
#  '             page\r\n _to the hesitating p',
#  '          page\r\n _to the hesitating purc',
#  '       page\r\n _to the hesitating purchas',
#  '    page\r\n _to the hesitating purchaser_',
#  ' page\r\n _to the hesitating purchaser_   ',
#  'ge\r\n _to the hesitating purchaser_      ',
#  '\n _to the hesitating purchaser_         ',
#  'to the hesitating purchaser_            ',
#  'the hesitating purchaser_               ',
#  ' hesitating purchaser_                  ',
#  'sitating purchaser_                     ',
#  'ating purchaser_                        ',
#  'ng purchaser_                           ',
#  'purchaser_                             _',
#  'chaser_                             _vii',
#  'ser_                             _viii_\r',
#  '_                             _viii_\r\n _',
#  '                           _viii_\r\n _lis',
#  '                        _viii_\r\n _list o',
#  '                     _viii_\r\n _list of c',
#  '                  _viii_\r\n _list of colo',
#  '               _viii_\r\n _list of color p',
#  '            _viii_\r\n _list of color plat',
#  '         _viii_\r\n _list of color plates_',
#  '      _viii_\r\n _list of color plates_   ',
#  '   _viii_\r\n _list of color plates_      ',
#  '_viii_\r\n _list of color plates_         ',
#  'ii_\r\n _list of color plates_            ',
#  '\r\n _list of color plates_               ',
#  '_list of color plates_                  ',
#  'st of color plates_                     ',
#  'of color plates_                        ',
#  'color plates_                           ',
#  'or plates_                              ',
#  ...]

# %% [markdown]
# We can now convert the text into vectors.

# %%
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Vectorization...
# <ipython-input-6-b1fdc504c468>:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
# <ipython-input-6-b1fdc504c468>:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

# %% [markdown]
# Next, we create the neural network.  This neural network's primary feature is the LSTM layer, which allows the sequences to be processed.

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# Build model...

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 128)               96768
#
#  dense_1 (Dense)             (None, 60)                7740
#
# =================================================================
# Total params: 104,508
# Trainable params: 104,508
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# The LSTM will produce new text character by character.  We will need to sample the correct letter from the LSTM predictions each time.  The **sample** function accepts the following two parameters:
#
# * **preds** - The output neurons.
# * **temperature** - 1.0 is the most conservative, 0.0 is the most confident (willing to make spelling and other errors).
#
# The sample function below essentially performs a softmax on the neural network predictions.  This process causes each output neuron to become a probability of its particular letter.

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Keras calls the following function at the end of each training Epoch.  The code generates sample text generations that visually demonstrate the neural network better at text generation.  As the neural network trains, the generations should look more realistic.

# %%
def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print("******************************************************")
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(processed_text) - maxlen - 1)
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('----- temperature:', temperature)

        generated = ''
        sentence = processed_text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush() # calling sys.stdout.flush() forces it to “flush” the buffer, meaning that it will write everything in the buffer to the terminal, even if normally it would wait before doing so.
        print()

# %% [markdown]
# We are now ready to train.  Depending on how fast your computer is, it can take up to an hour to train this network.  If you have a GPU available, please make sure to use it.

# %%
# Ignore useless W0819 warnings generated by TensorFlow 2.0.  Hopefully can remove this ignore in the future.
# See https://github.com/tensorflow/tensorflow/issues/31308
import logging, os
logging.disable(logging.WARNING)
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

# Fit the model
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=60,
          callbacks=[print_callback])
# Out:
# Epoch 1/60
# 1035/1035 [==============================] - ETA: 0s - loss: 2.0465******************************************************
# ----- Generating text after Epoch: 0
# ----- temperature: 0.2
# ----- Generating with seed: "at the foot of a pretty big pine, and in"
# at the foot of a pretty big pine, and in the had the strease and the streased the captain of the had a man and the showed the sead and the seaded and the had the bore the shower a man and the had a man and the come of the had bear to the had a man to the had a gan the had a man and the captain of the had a man on the seared and the show and the should a showed he had the had the some of the had the had the had a good a man the had a man
# ----- temperature: 0.5
# ----- Generating with seed: "at the foot of a pretty big pine, and in"
# at the foot of a pretty big pine, and in the seaside of the come of the boble, and the borg began to think see the sea--are and the saie seared and the that some and i was all the wast i came and the core his see all and the seaded the some a shind of the snot of sea to the it was i seiped and fit with the reder of so there on the had a mave all the bost some of the hard, and the whied the had on a come. and the had all a man and he had
# ----- temperature: 1.0
# ----- Generating with seed: "at the foot of a pretty big pine, and in"
# at the foot of a pretty big pine, and in the sore,
# bugre. even, and that's i i welu and or some
# eyolt strift. andly "or he how i "aed seeved men the every wave at fears, he to rop seatay puptawe; they
# corder, it not's corscake. i've i were toke a wook, a headet a tion hand bagainting
# i of sing, fite. and i saidew to, every now ofss. but a this at
# cation knowt gentur nex, a was andon, and the man arnor hever not mone kive somew acar
# ----- temperature: 1.2
# ----- Generating with seed: "at the foot of a pretty big pine, and in"
# at the foot of a pretty big pine, and iner havech and bety
# to
# i, now, sore,
# irto" hay s ed. gravy and for
#
# "! oft ve0d.
#
# ort; not made
# to everss
# man leg
# fle'sur bear thate captaysbew--sulks. yead of ele bight!
# . not beting. ifle of silvermed
# cosy, i'ctone i'll cabey enevorse out like badty aflhees, the captain wost of
# as bece.
# a , onf ours,ire a
# ook
# tol werr sunies, a was nverbearing frst.
#
# ruthen, he ild this phaces.
# 1035/1035 [==============================] - 123s 117ms/step - loss: 2.0465
# Epoch 2/60
# 1035/1035 [==============================] - ETA: 0s - loss: 1.6472******************************************************
# ----- Generating text after Epoch: 1
# ----- temperature: 0.2
# ----- Generating with seed: "re long
# tom, trusting that his own comr"
# re long
# tom, trusting that his own comrand to me to be silver with the sure and the side of the sailed to he sail to here and the still ben the side of the sure and the other the still to be should to be sailed to the captain and the stook to be still the trees to be and the silet of the trees to the silver of the still took and the sailen to the still to see to see to the side of the side and the sailed to see the stare of the sure an
# ----- temperature: 0.5
# ----- Generating with seed: "re long
# tom, trusting that his own comr"
# re long
# tom, trusting that his own comrant to be heard to shore of the main to the captain to be the strind and the signs me to the silet in the thind to stonting to silver in the strangly and still into the shore, and the face of the noge and seen the black be the old doctor the hands of the stand of the moment not one for the ware over worst down i see in the blind bike of the ship to me. before red with a speaking, and a tring, the
# ----- temperature: 1.0
# ----- Generating with seed: "re long
# tom, trusting that his own comr"
# re long
# tom, trusting that his own comray at as flatered in his your theirning prove. it say buccan in i  had
# night aoonds, treescaded breath
# wrone, i reapbesanting. but soon of the might un is a loy, saice
# of or another to or appotting
# of it , you daman to
#
#                                                                                                         g"
#
# ----- temperature: 1.2
# ----- Generating with seed: "re long
# tom, trusting that his own comr"
# re long
# tom, trusting that his own comraiding onfoared o-doacing moustion flat. been oadclewand. that
# "pensocet alousk old pleffeging deseak of the siwver's
# over
# aohenor,bted sotk, "you're to soon's eachorigh, for the
# taye, a black; at was as. i
# intemosher rum way more or with you ly soon, a
# mreat
# and done,
# a
# susp, were mishurek with have be enothisn."
#
# evens, "breough's airs and so surpeamed and soou had fye covers i was
# 1035/1035 [==============================] - 121s 117ms/step - loss: 1.6472
# Epoch 3/60
# 1035/1035 [==============================] - ETA: 0s - loss: 1.5378******************************************************
# ----- Generating text after Epoch: 2
# ----- temperature: 0.2
# ----- Generating with seed: "ing," says i; "i'm not going back to cap"
# ing," says i; "i'm not going back to captain and the stook to the south of the stook and the stook to the stook of the captain, and the captain said, and the captain and the stook here and the should some the captain and the captain and a sea and distributed the captain and the sure of the captain and the sturned of the stook to the bars and the stook the stook the captain and the stook the captain and distring of the bars and do with h
# ----- temperature: 0.5
# ----- Generating with seed: "ing," says i; "i'm not going back to cap"
# ing," says i; "i'm not going back to captain but come, when the
# doctor, and a man and said, he was for the should have an along of the cortined and all the northing the mustre to this comple to let the boat. and the blondles, and had put his handly and the fire, and it was captain and a shouton of
# the silver
# and a had been and be any roder his boats, and the stood we could he was to see which how himself for a captain. i had take the
# ----- temperature: 1.0
# ----- Generating with seed: "ing," says i; "i'm not going back to cap"
# ing," says i; "i'm not going back to captain quection,
# here croints
#
#
# endcyour from his stockaed, bf his
# faineld and the east pass, and her
# ; and i would do had, every told
# like a porch herventated and sponds arone a hound, if hible lookant and of or took, nearly one of boass, who his
# creaded on
# revery a cooks, for the cable
# sahe and now on
# conterds,
# h wood, some his certainly vising of hailside. i wasty, "his man terror of
# ----- temperature: 1.2
# ----- Generating with seed: "ing," says i; "i'm not going back to cap"
# ing," says i; "i'm not going back to capped--a etcin. nothin-sooniscalf capinclest
# that was why, he weather i munt
# blood ut his mounding. i fo
# ribals. "so
# give," said i, "i resnines, 'oubsmade, go alowing. there his pound, and
#        withing thies, upwasss and fif
# now
# which
# out- up upon !" firrt e?therewand with that.
#
# i were wame captain, you livesey, if your;'n up.
#
# "aw,"       "  t. man,, as a grem
# till a brotrey, much--
# 1035/1035 [==============================] - 122s 118ms/step - loss: 1.5378
# Epoch 4/60
# 1034/1035 [============================>.] - ETA: 0s - loss: 1.4775******************************************************
# ----- Generating text after Epoch: 3
# ----- temperature: 0.2
# ----- Generating with seed: "or
# corrupt data, transcription errors, "
# or
# corrupt data, transcription errors, and a struck and the stood of the treature in the stockade of the captain and i stood in the coracle and a strange and come to see the word his moment the stranger and a speak and the stockade and the captain and the cook the the stood of the stood in the stranger of the the stockade and the doctor livesey had a strung to the stood in the stockade of the word the stockade of the stick to the start
# ----- temperature: 0.5
# ----- Generating with seed: "or
# corrupt data, transcription errors, "
# or
# corrupt data, transcription errors, and the pirate and the southeath that she was sure a hands, when i as out of the this for a strange to chees went get the stockade of the fear him i was never the horse upon all the crew had been the stockade, and wet that i had never the colotered of this woods as i us a great the captain was sound the for at head was the stranget was men well, now under with a compain at the man to me
# the south
# ----- temperature: 1.0
# ----- Generating with seed: "or
# corrupt data, transcription errors, "
# or
# corrupt data, transcription errors, when it was with that held every the see ncoose head over betwened. i reveraty mater our tayes,
# and the stockade to craited tteess taking hew  begun that
# had, even seen to say
# the name,", for
# tell it, not
# the beringing
# compairnh that positions after
# victibuted a warder,
# shif that, bit nide
# so was held is
# nuff.
#
# "a man shore; as i'd necriess."
#
# "now i pale out like her, more kay, all
# ----- temperature: 1.2
# ----- Generating with seed: "or
# corrupt data, transcription errors, "
# or
# corrupt data, transcription errors, mades or a otabesclw, but
# which
# gon., the
# a hashel blong of moment, near though, but one
# mange to stect."
#
# "you epsered
# sail fintecy at lece, and he spys?" and now, gopet to cook seal the jimy-hoods
# fasiteifinly disnlabbest old?
#
#
#
#
#
# islant fita' pask; but eatt trown on
# the here the mindly, alrayperrug, speading,
# away in
# iner digsphait the
# churfaninedlh
# erves, belilew, my in sack
# 1035/1035 [==============================] - 115s 111ms/step - loss: 1.4778
# Epoch 5/60
# 1035/1035 [==============================] - ETA: 0s - loss: 1.4371******************************************************
# ----- Generating text after Epoch: 4
# ----- temperature: 0.2
# ----- Generating with seed: "d--"darby m'graw! darby m'graw!" again a"
# d--"darby m'graw! darby m'graw!" again a this and to see the start, and the still fresty and stare the still to like the still to the still fortune and ship the still fortune to the still man with the still to the still to the still to the still fresty started some the still beside the shipped and the still to the still of the still been the still to the still been the still to the time and sure the still breaked the stick and the still
# ----- temperature: 0.5
# ----- Generating with seed: "d--"darby m'graw! darby m'graw!" again a"
# d--"darby m'graw! darby m'graw!" again a good my pice, and you livese to to to time i had fectribution of the doctor to be the same to the worst of the captain and the sound his cover and passayed on the toon of the breakenes had all when i as i thought of the sure of the dead round the squire. but the bright still to see no still sure a little another and every this
# districe of
# some shore been word had a stranger with the start of th
# ----- temperature: 1.0
# ----- Generating with seed: "d--"darby m'graw! darby m'graw!" again a"
# d--"darby m'graw! darby m'graw!" again achors, but why," said i goked, livesey; sight to a more do'tly never livesidiyw know, bon oar tring out of him."
#
# "
# "well, if if it were
# you handed i'll
# a should of blick on ghome a stall my word gentleman.
#
# "now, lived deck, join and leaving hamber it, i reckon sichaeing stice pergining, never your conscance of his stowlightor, were shand of nock you to to re eeblisled a lifed-furing, ever
# ----- temperature: 1.2
# ----- Generating with seed: "d--"darby m'graw! darby m'graw!" again a"
# d--"darby m'graw! darby m'graw!" again again left this quirted the blockswars, from the all her  overhn way bavony treewward the swortknone had some them. and a tribal tifficaln giving, intolapp for the sowoned casle
# had rear files. wefory my boy, "jim ahwxny, muting at the beatishe, goitly her blow us, but say--her t"me-foom rother.
#
#
#
#  hawn orwlie-tislilon
# lowed a ro"gat. they had thom hisn, he door you lay, may the blonsh
#
# to
# 1035/1035 [==============================] - 114s 110ms/step - loss: 1.4371
# Epoch 6/60
# 1034/1035 [============================>.] - ETA: 0s - loss: 1.4097******************************************************
# ----- Generating text after Epoch: 5
# ----- temperature: 0.2
# ----- Generating with seed: " and found there was scarce an
# apple le"
#  and found there was scarce an
# apple lear to the sea and the stick when i had a man and the sail the corner of the ship was the stick to see the still to the stick and the cook. and and the cook to the sound of the sea and the cook his shipped in the sight in the stick to the sea and the same first and the doctor livesey in the ship in the still was the stick to the sea and the schooner to the broken and the ship was still was still wa
# ----- temperature: 0.5
# ----- Generating with seed: " and found there was scarce an
# apple le"
#  and found there was scarce an
# apple lear was not hands in the blind of the care
# of the sure and strind in the caller, and the signted one and a shipp that i was to see the
# till had state to the door in the works to the wind to be lounh of the endry. it was the wordser in the did was down to the hild and missiled the captain in the last, and the stiff of the one of the captain speak and seen one behind the same to the round the time
# ----- temperature: 1.0
# ----- Generating with seed: " and found there was scarce an
# apple le"
#  and found there was scarce an
# apple lest byed us
# atmind of sa" back on, but distributionkman and the , fien breaksmander was at the
# tate
# here
# were two becouss the man with were
# risals dmanced at on.
#
# cruse i..  was'patibled, firded. it was the ripped to bear. stell the surr,
# now of treas in the cook; evening an
# -and heind clear silver, and her
# mutire forchaved
# a sea-chest done mined the her. my thene ane the cor,
# rest
# kit
# ----- temperature: 1.2
# ----- Generating with seed: " and found there was scarce an
# apple le"
#  and found there was scarce an
# apple le;
# if was pads. "he'd the ploue
# was up prieyed, i't to hims lose skily what not, wwre
# dogetixion's, in the
# tir, of acrass, i would thail, and coom feely aedded thing.
#
# "ororgemen xcuted there would sunde-'s anilagen
# oraveds them never pawsormrymanly knew, unound huntloned, ill, and goadening---polusir in armain, silver--was ne't blew himgeent's smile; hepped,
# onci't to
# inlustrech, us.
# "we
# 1035/1035 [==============================] - 113s 109ms/step - loss: 1.4097
# Epoch 7/60
# 1034/1035 [============================>.] - ETA: 0s - loss: 1.3854******************************************************
# ----- Generating text after Epoch: 6
# ----- temperature: 0.2
# ----- Generating with seed: "r i went the brisker grew the
# current o"
# r i went the brisker grew the
# current of the cabin a sure the ship was stand the word of the story, and the ship so much and the ship still the count of the sand and the ship was the pleasanding of the stood of the still and the captain and straight to see the cabin that the same come and sure the stood and a strand the captain strange of the captain smollett, and the captain smollett of the stores, and the captain smollett of the sure
# ----- temperature: 0.5
# ----- Generating with seed: "r i went the brisker grew the
# current o"
# r i went the brisker grew the
# current of the borse and project gutenberg-tm electronic work up some of the cable hand and i a long the bows of the capped to the think the sure of the round the
# morning than the story, and the castanting and the barrel, and the best--the captain smollew, and dick and a place the project gutenberg-tm a monned out of a sure of a sure that was the pards and almost a sprange of the puller of the councker to
# ----- temperature: 1.0
# ----- Generating with seed: "r i went the brisker grew the
# current o"
# r i went the brisker grew the
# current of blow of pirasle freathisk.
#
#     more shadous long. sir, there had not watchess."
#
# and as luty oshe deferthed the shadous in
# nespess, from the gentleman for our been staring over face. in a sikent, you, i become, hard the bore of the stuty reasthing the rounds thundered my erryhuping
# out from the sutmon                                            id
#     his word.
#
#
#
# away," said me the m
# ----- temperature: 1.2
# ----- Generating with seed: "r i went the brisker grew the
# current o"
# r i went the brisker grew the
# current of dree, afret,
# and there mringgal emping me, folwelled the knar is xible with a
#  is.
#
# peyth me his sursvelfly
# ce?"
#
# seching, desealing, but not
# little friship hifon't. abflo, and, the
# old sea, troom
# goodil my firsthy was
# heasassed toetyment fringh anothing, i could have my breecashand it and is and laps unchbujentened with the
# chuered he vore, to a hill bring spriving overbe-sailars
# a
# 1035/1035 [==============================] - 113s 109ms/step - loss: 1.3856
# Epoch 8/60
# 1034/1035 [============================>.] - ETA: 0s - loss: 1.3688******************************************************
# ----- Generating text after Epoch: 7
# ----- temperature: 0.2
# ----- Generating with seed: "past the high lands and bowling beside l"
# past the high lands and bowling beside like a still began to say with the three before him the spot the corner of the spot the still way that we was the stockade, and the same of the still began to mounht was the stockade, and the still and sure that he was a still an old behind the still began to stared the starce of the still man and still state in the still and i says the spot that was the still below silver had been the stard of the
# ----- temperature: 0.5
# ----- Generating with seed: "past the high lands and bowling beside l"
# past the high lands and bowling beside land of the mischist that i says. that all had shot a monsing of the one of the three to the fears, and the south to the blockhouse, and we came and the speading that had beholder that we crull be sure a looks to the spy-glass, and i a passed and before the stardor of the beginning to the boat of the barrel of the mighty to the trees to that before us, and the doctor of the till it was down and a m
# ----- temperature: 1.0
# ----- Generating with seed: "past the high lands and bowling beside l"
# past the high lands and bowling beside left benbow althore a.
#
#       was you in thin you, my your beiling are ter. "you'll some
# last coff caigs, would have had of yindes, and not ussompwant.
#
# he had reviled the black-d.
#
# "and no risten."
#
# "than on'y dos, we know what you would
# have cload his first like some his tails and venituearil put as a band and a had a prokecuingly just me a spanues togepase on watery, and the death, and
# ----- temperature: 1.2
# ----- Generating with seed: "past the high lands and bowling beside l"
# past the high lands and bowling beside lookaner with a groon that do the
# farward, and a partt to
# wrole marganered mires, leass, now to weart, and i'll set his sailite; that long full forty topbully to the door seemed a'te
#
# "off me," and , cat
# gave to the unes,
# throew down that, that your rempinden, if he was, boon of timble far whereseevane, undine, but
# the work see hearly look and bort.
#
# you've time exacuely bed betocipher ,
#
# 1035/1035 [==============================] - 107s 104ms/step - loss: 1.3688
# Epoch 9/60
# 1035/1035 [==============================] - ETA: 0s - loss: 1.3551******************************************************
# ----- Generating text after Epoch: 8
# ----- temperature: 0.2
# ----- Generating with seed: " at the irreverence of his words.
#
# "be"
#  at the irreverence of his words.
#
# "before the captain.
#
# "i don't have that i have taken, and the captain of the speaking, and the captain of the story.
#
# "well, that all the captain."
#
# "well, that was a man was a stife and the captain of the story of the same time in the story, and the captain of the captain of the stife of the story. the captain of the stife of the heart of the sure and the sure a sure a stife and the story.
#
# ----- temperature: 0.5
# ----- Generating with seed: " at the irreverence of his words.
#
# "be"
#  at the irreverence of his words.
#
# "before the states to the see," said he, "i'll say, as i have all said.
#
# "i found that man's a piece, doctor," said i.
#
# "sir," said the squire's that mate before me and dispouth of the last of the story of the till was the stood of the sure in the partions cried the doot made as a sure a little head about the mainth here of the margh of the
# entrises and the island. he was the cabin my heads in t
# ----- temperature: 1.0
# ----- Generating with seed: " at the irreverence of his words.
#
# "be"
#  at the irreverence of his words.
#
# "before., i don't
# to be surred to the houred in a strena, of this
#  a cre; my's last my heart it were back.  queted
# in his cut withing plum or silver, out awas arving."
#
# "that was a- an" allowath he und other the long little now pive in the other was founse till hands-works old sia
# way over's
# stemped timishing the treasmoken and fow to our other all, he regrist
# carls he was all,
# even the mars
# ----- temperature: 1.2
# ----- Generating with seed: " at the irreverence of his words.
#
# "be"
#  at the irreverence of his words.
#
# "better 'ng good,"
#
#
# i was appear.
# "befoursite--a; and to
# skele
# good,rast
# after of yef."
#
# you was anqureh lock," said.
#
# sirlans, adproten. fortht every stopoth, only
# herm up do you grans he snhooenging nom contince and headmy. tamfeed deschible.
#
#  , and or livesey, me,
# you nabeerstaps, very father, treasute his blift still stards, and a flow storif his man.
#
# that was no sonned his vo
# 1035/1035 [==============================] - 105s 102ms/step - loss: 1.3551
# Epoch 10/60
# 1034/1035 [============================>.] - ETA: 0s - loss: 1.3414******************************************************
# ----- Generating text after Epoch: 9
# ----- temperature: 0.2
# ----- Generating with seed: "ned the captain.
#
# "livesey, that must "
# ned the captain.
#
# "livesey, that must have to still man and the same canton of the sure that was a silen to come to a persor of the story of the sound of the stick of the stick of the captain smollett was a strengers, and the captain smollett of the stick and the captain smollett of the captain smollett of the captain, and the captain smollett of the bottle of the captain smollett of the stick and the captain smollett of the stick sho
# ----- temperature: 0.5
# ----- Generating with seed: "ned the captain.
#
# "livesey, that must "
# ned the captain.
#
# "livesey, that must so he had been the captain of a preceibureral hands, and the south on the captain smollett of the most in the south on a prosiness to leave the stochast of the next brust of the fire of the project gutenberg-tm were all warr, and the boats was every sailor. "i had
# to came he was a pipe, and you
# waited of the stick was a narrow spread to treasure he was mark a had a hands, and the captain and a s
# ----- temperature: 1.0
# ----- Generating with seed: "ned the captain.
#
# "livesey, that must "
# ned the captain.
#
# "livesey, that must flicken shoulder, now the pirit of and come him oat a
# boat than i wands cut to dre"anderrushed, i've i hid aprouther lightly haady might long john. stapped
# in the bars. "how his
# piratery's pation, not here," said silver. "i do not'll it i last, and were i through the
# lame of ne, he had
# screle was no more captain, purtulained to be instorted
# with withoutt turning wonder. i never held you shou
# ----- temperature: 1.2
# ----- Generating with seed: "ned the captain.
#
# "livesey, that must "
# ned the captain.
#
# "livesey, that must ge wyate," cried i could soon a forth,, and the cabin lay in vaious og into gunwair, and so the pipe of the
# air--ashoreire of hit prcatherence chiecel! jimaglikent
# frost enoigh of the presental. and      the captain et'er rockners's way, and
# fird
# with a breaked on viywleance for a ons work yit injust max        tuen something borke himselterves muck to. i raptor
#  some necrying tile all on.
#
# 1035/1035 [==============================] - 105s 102ms/step - loss: 1.3414
# Epoch 11/60
# 1034/1035 [============================>.] - ETA: 0s - loss: 1.3318******************************************************
# ----- Generating text after Epoch: 10
# ----- temperature: 0.2
# ----- Generating with seed: "teau was dotted thickly with
# pine trees"
# teau was dotted thickly with
# pine trees he was a still a sear.
#
# "and the captain, man was a sure a shoulder to captain smollett, and the captain smollett of the captain and the captain of the story of the story of the sure a sure and the captain and the captain smollett, and the captain of the captain of the story, and a man and sound the captain smollett, and the captain smollett of the story of the sea and the sure a man was a set
# ----- temperature: 0.5
# ----- Generating with seed: "teau was dotted thickly with
# pine trees"
# teau was dotted thickly with
# pine treesines to brass, one as a coured and disclaimes and a man in a sound man of the corner, and the stuping look and a bet you give you see that sepped on to this her came of the cut with
# wring the six spoke
# sound to see the captain is a crew and the gigs; and the deck was the colice and sure and party the county neared the other body
# up that the other, and then his planed in the captain of the bowst
# ----- temperature: 1.0
# ----- Generating with seed: "teau was dotted thickly with
# pine trees"
# teau was dotted thickly with
# pine trees dog
# bowen; and there mark on the mutinal,
# hail
# when that ran, with man's ungets, these rumy
# made
#     whan among to the
# sundredent, captain smollett, discledibk-con tatious had dropancess, before it was found, but that aboard than compenous, to like talk through the sailing to have ourne,
# die wading i like as i pleast known the slael, pault hawkins
# completed to tax than
# .
#
#  rement for a
# ----- temperature: 1.2
# ----- Generating with seed: "teau was dotted thickly with
# pine trees"
# teau was dotted thickly with
# pine trees medie of hward this
# black-lath, and leor safection did yout have a, externaned, by spided moing where i
# recmoverly on the own madist to to be berrinions water
# that a nake from the chart was sent would ry-ticled, you've, to
# koal se-ceast, i sto came slowing, the wiell. herg gurn in bowned thing us, froggances, thry to, like. welwand; behind ly hers's clotth, to than si!jidening in moved said
# 1035/1035 [==============================] - 106s 102ms/step - loss: 1.3318
# Epoch 12/60
# 1034/1035 [============================>.] - ETA: 0s - loss: 1.3247******************************************************
# ----- Generating text after Epoch: 11
# ----- temperature: 0.2
# ----- Generating with seed: "
# spy-glass on my right hand loomed faint"
#
# spy-glass on my right hand loomed faint of the still and the still boat sailed the first went of the still and the still and the shoulder of the still of the stockade, and the boat said the still of the still and the shoulder of the shipp and the still of the stockade, and the course of the shoulder of the still of the stockade, and they were all the still showed the still of the still of the ship had stared the stockade, and the capta
# ----- temperature: 0.5
# ----- Generating with seed: "
# spy-glass on my right hand loomed faint"
#
# spy-glass on my right hand loomed faintered, and the shoulder of the stick to the log of the meticuliest help had
# head with the stockade, to stoul
# with the sure to a maners was pines of the shoulder and a drether to have to the tilled of the sure in the others was gun in this shot bean to low hill spoke him the was bearing courses had
# the stine of the fire of the mind of a thing the most to the sound that he should now showed his co
# ----- temperature: 1.0
# ----- Generating with seed: "
# spy-glass on my right hand loomed faint"
#
# spy-glass on my right hand loomed faint afbellows who had
# onride would lyound it come tratemeny one of refevil the woods, had been the pair of the coom, and they chave, silver,
# - in
# the hapdry or lived heright
#
# this suppose, and round carrig, that make in himselves
# obanders. then.
#
# i am other was figing about i was weared startury in the desirien and
# the water ownithing left enough, the more or feet besomen rums. but this' we
# ----- temperature: 1.2
# ----- Generating with seed: "
# spy-glass on my right hand loomed faint"
#
# spy-glass on my right hand loomed faint the maulhe of great breath; speaking, for the sepreming; but i had ever tile a humplinctive upan for anslipped
# they couldn hardleffow, and it's elved to to more to cap'nis's day
# corncauping oneherness, to tolting the tirforhlather swemence our
# hollows had a dugiray,
# he
# thought ooner, ."
#
# at ivers and haver him pipal the vispatious so more eterner skepors. why
# tonders," said ioneing gut ho
# 1035/1035 [==============================] - 106s 103ms/step - loss: 1.3246
# Epoch 13/60
# 1034/1035 [============================>.] - ETA: 0s - loss: 1.3255******************************************************
# ----- Generating text after Epoch: 12
# ----- temperature: 0.2
# ----- Generating with seed: "k and get some work."
#
# and then as i w"
# k and get some work."
#
# and then as i was a stood and still to be the captain was growing a sure in the color and state in the captain was the captain was a soul and done and state and started the captain was the captain was a sure in the color and set of the color and companion a sure in the coracle of the color and distring the stood in the captain was a sure to the state of the cook or the cook of the cook out the story of the capta
# ----- temperature: 0.5
# ----- Generating with seed: "k and get some work."
#
# and then as i w"
# k and get some work."
#
# and then as i was that we with the coines of the copyain strange and drink the throught of the sun had hand masted in the island to the colacce, and not he was a seen the portrignt, and starter, i thought it, and we had the course of the stick into drange on the pilling a chare of the captain was started the captain was seen the man before a have said her bearing took the parratureness in the coracle call out of
# ----- temperature: 1.0
# ----- Generating with seed: "k and get some work."
#
# and then as i w"
# k and get some work."
#
# and then as i was
# mrosle a sing to project rigged to everythirs."
#
# and keeped. jim,
# and the sign od runned gentlemating to so made got absilves, i never
#    about. he had i had havinablanded and decilg her perace to like
# teasion this shot of the distons were weath more lad, when. not help on. "don't--sorad that's. i got last. jim, here, you
# know the soleming break hill hean to tetch cried. some. again," he
# ----- temperature: 1.2
# ----- Generating with seed: "k and get some work."
#
# and then as i w"
# k and get some work."
#
# and then as i went ppoot. isef--glast
# to, all as a state, beach crroyat. i
# ? ohe hearnce they said in
# that was black-doling boy--the tooncace he were ad, we began, 'us--time." we were now it is on me tumine. in-heavent, we'll doctor, when to see wet, like a land bucchay ocknems.s blaguit?  ighd. huriey i volade, there.  wal all theh, how me. tle there is i had. forgine this said, but two becosches;
# i would
#
# 1035/1035 [==============================] - 106s 102ms/step - loss: 1.3254
# Epoch 14/60
# 1034/1035 [============================>.] - ETA: 0s - loss: 1.3100******************************************************
# ----- Generating text after Epoch: 13
# ----- temperature: 0.2
# ----- Generating with seed: "de."
#
# we brought up just where the anc"
# de."
#
# we brought up just where the anchorage of the woods in the stockade.
#
# "a bottory on his here," said he, "than you dis'tus?" said he. "i'm the boat, and i had since it was the captain of the sure to the wood, and i was the captain sure to the wind of the sure to the boat, and the storight and the captain was the house, and the captain was the sure to see the captain was the captain was the worst and a sure to the work and the c
# ----- temperature: 0.5
# ----- Generating with seed: "de."
#
# we brought up just where the anc"
# de."
#
# we brought up just where the anchorage with his time, i could his hands to see the worst in the for there was the morning in the blockhouse, and with a sure, and i was be set here, and the nailes to put of the house, was a seaman, by the jolly-boatspany, and the horring to the
# rishly with his shoulder
# of the blockhouse, in the
# sure to his old bright on his her the doctor with the storing companion, and a presente on the parlo
# ----- temperature: 1.0
# ----- Generating with seed: "de."
#
# we brought up just where the anc"
# de."
#
# we brought up just where the anchorage hurry on them along the
# sometweendering usite of a momen. she ."hurlang on a manery other the bit of done these under another marboart.nver blagn should be moncen to assace sittinionater to turning among stocgle.
#
# "as here's airn, as we'll hand. we'm was so on!" with wark, and
# far below the walk. out acssed their wood stansing, had not a drarled over, him in the stageless hands and you
# ----- temperature: 1.2
# ----- Generating with seed: "de."
#
# we brought up just where the anc"
# de."
#
# we brought up just where the anchoragijus purtush dit on whem it cass, hole infurnas gamebenenly been ontaction a behieve fieclying
#  put trath isloiding brawing figure should risk, faging
# remout bbeapped , plannion, john, ulmool. flagu di; and a beainced scran he lang he hadining at the
# sann-boty fire watchd. wretted my end.
#
# a nogrehns; flibiting "beft the bally, even that slittle famein ent compation centival bahond to th
# 1035/1035 [==============================] - 106s 103ms/step - loss: 1.3099
# Epoch 15/60
# 1034/1035 [============================>.] - ETA: 0s - loss: 1.3027******************************************************
# ----- Generating text after Epoch: 14
# ----- temperature: 0.2
# ----- Generating with seed: "
# shameful gibbet that awaited him.
#
# "
#
# shameful gibbet that awaited him.
#
#
#
#
# chapter x
#
# the captain was a state of the stockade of the captain the captain the captain the stockade to the boats shore and so surn the stockade of the thing the corder of the stockade and statue a sound and frold the stockade of the corder of the stockade of the stockade of the corder of the boats. i had a stockade, and before a spoke and doctor livesey, and a state of the stockade of th
# ----- temperature: 0.5
# ----- Generating with seed: "
# shameful gibbet that awaited him.
#
# "
#
# shameful gibbet that awaited him.
#
#
#
#
# chapter xxiv!
# the captain had desting the other captain to and get a behind the captain to let the rest of the word of my man, and a little of the poor captain the gun we were found the roughand shore, and the word of was start in all the captain the stake going to like a streadition of the deck, and tell idlest a good is a sand we was when they were for the other was a spraig to the project
# ----- temperature: 1.0
# ----- Generating with seed: "
# shameful gibbet that awaited him.
#
# "
#
# shameful gibbet that awaited him.
#
#
#
#
# chapter gup do you akeris; but junt from the leafing had come to their end and that the dark we gan changreaged year, and pgot lig's mut surreasely they, bound the bowsiling.
#
# "a sir."
#
# the ch rought rest a spouts;
# "sid," cried., old bound pintibe, and the chip
# end. for i clearther of fure to give
# long agounand discludins to knore with slow their heards, when the soon and shade up hund
# ----- temperature: 1.2
# ----- Generating with seed: "
# shameful gibbet that awaited him.
#
# "
#
# shameful gibbet that awaited him.
#
#
# tusted as here
# siever. i pew! jim of inseid."freiblingr of chareche, air. mr. sheee
# blood of friends.
#
# but i askan gidle that was tnoo oftrchorgen; "we've no-sawder, hawkins,''s-e. they go't answere firn po, with thpce for spread.
#
# cried set the bo-dowed
# tobout i
# had linded with hards tratch run to sure, when you my lift. "i've came statten. .""hbold, i wasne?" he relied the captain voice
# 1035/1035 [==============================] - 107s 103ms/step - loss: 1.3027
# Epoch 16/60
# 1034/1035 [============================>.] - ETA: 0s - loss: 1.2928******************************************************
# ----- Generating text after Epoch: 15
# ----- temperature: 0.2
# ----- Generating with seed: " moment a
# pistol cracked in the bush, a"
#  moment a
# pistol cracked in the bush, and the stores. the spread and the shoulder of the stores. the sea and the country of the shoulder of the coracle and the party of the shoulder of the shoulder of the stockade and the country, and the sea and the country, and the country, and the stores. the stores. the sun he should he was a side and set of the stores. the stores. the shoulder of the stockade, and the sure to the country, and the
# ----- temperature: 0.5
# ----- Generating with seed: " moment a
# pistol cracked in the bush, a"
#  moment a
# pistol cracked in the bush, and all once my mother was a regress beside a betilily among the stores of the same time a beting on the thick was a treasure-hunt--and a state by the worst and luthing the coracle bustly and the store in the shoulder of the stockade, we a joncomed before a stern the stockade, and
# the signgntly and a with a sicling and stare
# and spout me. if the woods. and the country, putch of the time and done
# ----- temperature: 1.0
# ----- Generating with seed: " moment a
# pistol cracked in the bush, a"
#  moment a
# pistol cracked in the bush, and, but
# thinding my hooled to this own soft. from a reschy, i predureguted at lagnes
# close the chest the ship's back uponeion hishy, and, but, he pooch faver, of his feet-farow stroable get like, they was now is from the trees. sir, where the long moneyber of for cover desan other chitces and grafe your piece of a. what a unclfice it for a stupinions, and that doubb!adcannered the othors.
#
# "if
# ----- temperature: 1.2
# ----- Generating with seed: " moment a
# pistol cracked in the bush, a"
#  moment a
# pistol cracked in the bush, and
# this; hispeck to doctm, scroughts, and right
# ove way spreightious at latt lie? he apteer vollest if the heag of the flack of ahikes up in a truch hauled his lac; wevilly issawitiong
# lieward
# back away old sound be-hweet, anyohe instex. the nearerns! or myselveisition. shipmyander,
# whhe natirhay walk i had knees i camtain for tamce mins of bormen, hundent
# four
# and the man and
# cot dropod t
# 1035/1035 [==============================] - 107s 103ms/step - loss: 1.2930
# Epoch 17/60
# 1035/1035 [==============================] - ETA: 0s - loss: 1.2859******************************************************
# ----- Generating text after Epoch: 16
# ----- temperature: 0.2
# ----- Generating with seed: "nd we'll put it, if you
# like, that that"
# nd we'll put it, if you
# like, that that's the stake a song and the stockade, and the sea breath of the stockade, and a man and were all on the stockade, and the stockade and were all seaman, and the stockade and the same time and the stockade, and the stockade and the stockade, and the stockade with the stockade, and the same too my beliefe and the cook of the stockade, and the stockade, and the stockade of the stockade, and the stocka
# ----- temperature: 0.5
# ----- Generating with seed: "nd we'll put it, if you
# like, that that"
# nd we'll put it, if you
# like, that that's singing and i spite for the coing address reasure before a startaun was plainled thrown and the companions as they consaid of the spring with a little ben gunn into my words and the schoons of the scroad. the color old have the stockade to stood his all holding the first at the sound work heav of the sure place to get at the foot of the three breath of the companion stroad to meer the stockade
# ----- temperature: 1.0
# ----- Generating with seed: "nd we'll put it, if you
# like, that that"
# nd we'll put it, if you
# like, that that don't been struck by them. as we arns straigites.
#
#
#
#  rettment me against the
# redrest hand his
# starter thing as went thly-glass, and sure to my so once shored thing no time
# as into throundaghtcame, and
# you with three he rep.
#
#                                                                               "
#
#
#
#
#  pardibuting to the bly once of dick--druck the ball of wokes.
#
# "come,"
# ----- temperature: 1.2
# ----- Generating with seed: "nd we'll put it, if you
# like, that that"
# nd we'll put it, if you
# like, that that's the to
# jumiry, you ared to his tradk--"pew.shering blest . you ored reasicly isapming point--off off."
#
# "ullows on, mays.
# sirs
# mean a
# chelberway with
# at the linggly would take it shoo and steed thing, abmeachos addepled my med, cleaninging cxmquanding before with this amopsait,
# but idligitly through herp mesponing came belowed mo threw yreacced. "thundinks and what last that, buld just.
# 1035/1035 [==============================] - 107s 103ms/step - loss: 1.2859
# Epoch 18/60
# 1035/1035 [==============================] - ETA: 0s - loss: 1.2806******************************************************
# ----- Generating text after Epoch: 17
# ----- temperature: 0.2
# ----- Generating with seed: " order were given, john would be on his "
#  order were given, john would be on his shore--and the stockade, and when the same carries to the doctor was the man that was not one of the stockade, and the same to the stife of the black spot and a shore and a sound the stockade, and the captain shore. the stockade, and the stockade, and the same to the shore--and the stockade, and the captain story of the stockade, and the same to the stockade and with the stockade, and the same bac
# ----- temperature: 0.5
# ----- Generating with seed: " order were given, john would be on his "
#  order were given, john would be on his head we was the companions in the spore of the captain--and a pipe of the boats was a swalmed on. i made her the coracle came to mean stripped about our old woods of the moracal horsed the streamorusk at last to the worst had a good stoncess round the door and the cood of the captain was a shore, and a bottle lay stare and sail the captain smollett wast aside at last in the sails of the man strang
# ----- temperature: 1.0
# ----- Generating with seed: " order were given, john would be on his "
#  order were given, john would be on his partable activulantions among the old the mrie soon. the worst and the wrochanions
#     younly."
#
# and while i back as if anowning
# the sead. on berginapes
# began; his ampock some of watge" heard."
#
# and at the worse in the chestem, i must have
# a ticling the shore
# string am
# bolling afray
# his pew.drepoy
# ase with paula exiping the captain, which we coul! open stmandows wdical man wen goingly
# ----- temperature: 1.2
# ----- Generating with seed: " order were given, john would be on his "
#  order were given, john would be on his gall ma'e
# her, not the froncito-shoulded; and her as that had in form
#
# but,s siily to md you is beyow! i could hear well, this airde--andore life, and when i for dead none home on out in squiree
# us,
# new hear fine no dre pace
# another cacters to askednment
# bebong-y-capt, for morgan.
#    had our tomt
# zyouble angume the more,
#
#
#
# party-f
# , and just by
# - youbs--glad. "you're "morgain,
# for
# 1035/1035 [==============================] - 108s 104ms/step - loss: 1.2806
# Epoch 19/60
# 1034/1035 [============================>.] - ETA: 0s - loss: 1.2726******************************************************
# ----- Generating text after Epoch: 18
# ----- temperature: 0.2
# ----- Generating with seed: "ere nobody puts in but
# gen'lemen of for"
# ere nobody puts in but
# gen'lemen of format seaman, and i was a councal was a good still have the captain shipmate and sun a man of the man that so her cantrion of the stick was a man and the captain shipmate, and i was a man that i was a man was a man of the work of the chart.
#
# the same captain smollett was a man was a sight of the boy, and the same compain and a man was the man that he was a project gutenberg-tm consone of the trees
# ----- temperature: 0.5
# ----- Generating with seed: "ere nobody puts in but
# gen'lemen of for"
# ere nobody puts in but
# gen'lemen of formence."
#
# "why, sir," said silver, "i'll with the sight, and then the man and a sure of no made him the man with still trees--that was not were all the began of the man that he seed the captain smile the sand of the wark, and the gambering and the captain stand corner and his man through the color of the boat sand, and the hant of the way of the morning the arroush of the back. and then we had fo
# ----- temperature: 1.0
# ----- Generating with seed: "ere nobody puts in but
# gen'lemen of for"
# ere nobody puts in but
# gen'lemen of fortune
# reamon, allad iotay being faliges now, all you!"
# itted my men to have with his agreen, your's lettered the forture
# seledn that i was it. the foundal of a hundred .  excaped siche. sound abour just to heers, at ile, and the numbering of a present yeors fost making
# the
# run enough, a have cull frightn pipilioned plain and can with a rot have a long to and gettle into the
# sleep of
# into the
# ----- temperature: 1.2
# ----- Generating with seed: "ere nobody puts in but
# gen'lemen of for"
# ere nobody puts in but
# gen'lemen of forty
# oneal printed,
# he or down; with the reflimming the,"     found a day, which laddey, a motions and disglacer--'fuun shot,
# you, mericaaly, anspere's," sike you say, my secondlrbgard as a setsing, was of not has some time they gidon voacah, and i was eatnor, i not longer          jung, hurlsuan asvertiousled side
# nover every muter, and the hunrad
# by jun yor this after their come
# him. , indea
# 1035/1035 [==============================] - 107s 104ms/step - loss: 1.2724
# Epoch 20/60
# 1034/1035 [============================>.] - ETA: 0s - loss: 1.2658******************************************************
# ----- Generating text after Epoch: 19
# ----- temperature: 0.2
# ----- Generating with seed: "s in
# the main, could neither be led nor"
# s in
# the main, could neither be led north
#
#
#
#
#
# chapter xxv
#
#
#
#
#
# chapter xxv.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# chapter xxv.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pourtionage the course, and then i had soon the stockade, and the captain some of the stockade, and the captain smollett was a could be about the stockade, and a course of the stockade, and then i was the coracle of the boats, and then i
# ----- temperature: 0.5
# ----- Generating with seed: "s in
# the main, could neither be led nor"
# s in
# the main, could neither be led north, all had a course, from the house were all hang at fount, and as i was besiden his mouth and the captain smollett; and then the course, when they were with himself at the blockang of the brokst course to see him
# so he had starining the house of the story and while is a sure of my stretcther had falling the stockade, and was flint's still sight that i see the stores, while i could see the shoul
# ----- temperature: 1.0
# ----- Generating with seed: "s in
# the main, could neither be led nor"
# s in
# the main, could neither be led north, with a
# said of might.
#
# "and then!" he coalden to him at," said they happy word," said hozed, "that every wound so ralcen sway, and do it quibl, at raped, would lool frow and goanted open surpright sort, i must burse of a."
#
# "i could you, to,"
# your moment being and. you misking on which," you more!"
#
# "sign."
#
# "ah!" friend. sill men towed a leate as case close back.
#
# "there's a betin
# ----- temperature: 1.2
# ----- Generating with seed: "s in
# the main, could neither be led nor"
# s in
# the main, could neither be led north
# awanting aar; are
# along though of ermos.
#
# as far porty man araltely, for the we do
#  sey ious empisideed my old
# for
# that him alounding and word, but youngo a fro'll pain," clobank luby. -or off there."; looking, till
# sengs soon a. pleasing, and.
#
# "and as you parttuonal.
#
# we weren insearautish? with," asked they griess the
# xisly would sailhess
# oou engfpet, a surmigbooung on. to se
# 1035/1035 [==============================] - 108s 104ms/step - loss: 1.2657
# Epoch 21/60
# 1035/1035 [==============================] - ETA: 0s - loss: 1.2609******************************************************
# ----- Generating text after Epoch: 20
# ----- temperature: 0.2
# ----- Generating with seed: "still raging,
# another sound came from t"
# still raging,
# another sound came from the sure to the sure to the same time and the ship was a sound and the same time and the same time and a pipe of the sure to the house of the doctor, and the captain smollett of the ship with a ship of the stockade the stockade the captain and the same time and the captain smollett of the same time and a companion of the ship were all the time i had seen the sure to the shoulder sail the stockade,
# ----- temperature: 0.5
# ----- Generating with seed: "still raging,
# another sound came from t"
# still raging,
# ...
# ----- temperature: 0.5
# ----- Generating with seed: "mirror, was exactly
# portrayed from the "
# mirror, was exactly
# portrayed from the balling of the bright clearty and briskly to say.
#
# i am saw her before the sail about the creak and the parled
# had been the house, and every hands was breather and fresl hands that our same that i saw bear at the time of the thing these and the boat shipmens and the captain ships, and i would see they are all through the sundances, and all hands not casted
# been me in the thing the ship, and th
# ----- temperature: 1.0
# ----- Generating with seed: "mirror, was exactly
# portrayed from the "
# mirror, was exactly
# portrayed from the to-ard lay them and i'll tell you. all a mouth stade."
#
# i was plain paintly
# another in the marshing, as they were all this her about i fancy, or terror.
#
# "you've out by tricled that start right
# you mount began the tyout low tralemark--trea mince pass ashore, by the boy, "well, who reasaved, tos.
# "i purlow
# that shoped, if holdong dill, but clean from designed in a great way,
# like all, reco
# ----- temperature: 1.2
# ----- Generating with seed: "mirror, was exactly
# portrayed from the "
# mirror, was exactly
# portrayed from the verroquem, we stuppliett--ayber, cready, nigd's clefther, had
# "gone," mrontain. that he was.
#  he none distribute gom's jelly, slipf wet, this was in musk to finude standy corner, youngers glare and i
# saw show bod, sit im even was we're'nd his face thoul, o'llow of same that. there's the
# srough at fitter
# your missiother; and, as wign accops
# into down the luff acffuped of the
# second and said
# 1035/1035 [==============================] - 110s 106ms/step - loss: 1.1581
# Epoch 55/60
# 1035/1035 [==============================] - ETA: 0s - loss: 1.1550******************************************************
# ----- Generating text after Epoch: 54
# ----- temperature: 0.2
# ----- Generating with seed: "ilver! don't know him. who's he?" cried "
# ilver! don't know him. who's he?" cried the captain. i was the captain the stockade of the captain of the stockade of the stockade of the stick of the captain of the stockade, and the stockade of the stockade of the stores, and the captain of the stockade of the stockade of the sailore of the captain of the stockade of the stockade of the stockates of the stores, and the seaside of the stockade of the captain of the stick of the stockad
# ----- temperature: 0.5
# ----- Generating with seed: "ilver! don't know him. who's he?" cried "
# ilver! don't know him. who's he?" cried the captain. i was a charging should the ship with a good beginning of the room and the start of me succes. i was the winds of the boatswain
# of the ship and come to the pit of the ship had been the schooner of the plain was
# here still striping of as we began to wanting the captain, and i good before him over their doctor livesey, and the permest of the torch of the stick of the captain of the ca
# ----- temperature: 1.0
# ----- Generating with seed: "ilver! don't know him. who's he?" cried "
# ilver! don't know him. who's he?" cried the cut steilt hamrown the
# had
# old behind husing he
# broken.
#
# "look light?" often was word, can xvings and beluder's farrugnt is buh.
# a sheifle lamne and i scem
# ward around fly
# emply.
#
# but there before i wanded to see the whotes was ditled their headrmby
# close besides. our us of the basite burnting posed as cap. withind
# took what no had beach honess sat
# compance munning. the had been am
# ----- temperature: 1.2
# ----- Generating with seed: "ilver! don't know him. who's he?" cried "
# ilver! don't know him. who's he?" cried the moking watchels it i
# maved companions into the most paraled it
# was, inclapited offace one elicget his deenious them to the
# right,
# his otherss of bill, oppoods. keep fro, and leasion, obseads, you
# sayse i pigeny
# from their while that's death here i had redimines, noisness, that i was briguitly we
# the swipple--"make you; and nithers soon't once; if
# a child here--the while seeline doquat
# 1035/1035 [==============================] - 111s 107ms/step - loss: 1.1550
# Epoch 56/60
# 1035/1035 [==============================] - ETA: 0s - loss: 1.1523******************************************************
# ----- Generating text after Epoch: 55
# ----- temperature: 0.2
# ----- Generating with seed: "y--" i began.
#
# "perfectly right," he i"
# y--" i began.
#
# "perfectly right," he iden the captain, and the black dog
# and the party of and the color of the three of the trees of the sures, and the trees and the same corse and the color of the same corse and the same corse and the same corse of the sure of the blockhouse. and the man was a suddenly that was for my sea--the sure of the same corse and the same corsently and the same corse and the same corse to the sure of the same
# ----- temperature: 0.5
# ----- Generating with seed: "y--" i began.
#
# "perfectly right," he i"
# y--" i began.
#
# "perfectly right," he id a man for the chart of the morning of me to be sure, they was things to see the party of wat i could have my mother to the loophole, and the first of the same cork and the beside monse, as he had in the sure of a child and the color of the thing lad even the thing to put the dead time and seen the party of the spowd shipmate of the three them, and the cook
# courale is that had come to the taste
# ----- temperature: 1.0
# ----- Generating with seed: "y--" i began.
#
# "perfectly right," he i"
# y--" i began.
#
# "perfectly right," he id
# no. silv's wood or for put here and you share of hundry to prodat, from or burno, and you are, your mouth of these so long thinking on
# flinting and mr. then was that was
# 'new three good," said in the ancher of think had deserd, for all in the wrech of the sand again of you, sir.
# ; mahat i saw flee their she
# had, some
# throng about, all
# ss the spo, as deadled so the seaking some planside
# ----- temperature: 1.2
# ----- Generating with seed: "y--" i began.
#
# "perfectly right," he i"
# y--" i began.
#
# "perfectly right," he imost of dead swipmed. if we
# may have found
# mindly on, we must, all, did you are. roop? i say you?" firsessly, with my heart distress copy.
#
#
#
#
# chapter xx. if cound; and if and sjat! our, and i
# seen where ired by the so
# of before the mutineers, silver. if you the pine of
# save of my
# bwb, i began to am
# head
# i added you that," said the dettoe to the lope, reaved by his
# couch was founding
# 1035/1035 [==============================] - 110s 106ms/step - loss: 1.1523
# Epoch 57/60
# 1035/1035 [==============================] - ETA: 0s - loss: 1.1519******************************************************
# ----- Generating text after Epoch: 56
# ----- temperature: 0.2
# ----- Generating with seed: "but even a small change in the dispositi"
# but even a small change in the disposition of the broad of the stockade, and the stockade, and the stockade, the stockate, and the blockhouse and the black spot and seen a state was a stort, which was the black plact and seemed to be some bad the stockade, and the stockade, the stockate, the whole ship was a state in the stockade, and the whole shoulder of the stockade, and the stockade, the stockate, and the color of the stockade, and
# ----- temperature: 0.5
# ----- Generating with seed: "but even a small change in the dispositi"
# but even a small change in the disposition of the sailor, and a skind of the thing to help by the sea toward the mastle and long john sight the sea about held the blockhouse, and with
# the same carrowing the sight and still was a soul slowled the corner of providing the stockade, and the part of the project gutenberg to were the worst the bold, which he open the last way with a good work; and, i don't the toon and seen the matter of the
# ----- temperature: 1.0
# ----- Generating with seed: "but even a small change in the dispositi"
# but even a small change in the disposition down the cave, of the foundation's trum and i.       "ay, and you'll be captain, sperrit my nech. the might mast! i'm going till i can down. well, keeted in
# the space, by that then began to get itself us froll ebor seemend, onles where he earte
# peaceful
# for stinuin by some for ter was agrig the forousleae of about a pipteed sit weren a partifaross. like a stool with death wen gluer and was
#
# ----- temperature: 1.2
# ----- Generating with seed: "but even a small change in the dispositi"
# but even a small change in the dispositity.
#
#
#   la? mates to time a good brokst
# loves, thumsex of
# no. charis sojking
# enoughhr's indily
# 'un't the chart'uled," said i, "it's looke; and me, i stow whot i recoone, a quidpair of you. turnainerage, call its mr. the loor
# was so much job
# my de
# time acreak du; ah, bee, there was or beliel same, as a unppation his used the worn, for a si-tangad
# down, who had not lowlh no, fies, thio';
# 1035/1035 [==============================] - 110s 107ms/step - loss: 1.1519
# Epoch 58/60
# 1035/1035 [==============================] - ETA: 0s - loss: 1.1531******************************************************
# ----- Generating text after Epoch: 57
# ----- temperature: 0.2
# ----- Generating with seed: " replied captain smollett. "easy with th"
#  replied captain smollett. "easy with that shipmated me to see the mainsain and seen the color than i had seen a hands and the companions of the broken of the sure of sailion here and so her coming the captain of the stockade, and then he was the sure of schooner than the supersion of the captain of the sun had been the same carachous the captain of the sailor, and the same caraclar the schooner that i had been the corner of the compani
# ----- temperature: 0.5
# ----- Generating with seed: " replied captain smollett. "easy with th"
#  replied captain smollett. "easy with the door," cried the doctor. "but i'll go a project gutenberg-tm end between my nearell he should see the sganle were all hands were you a side of a sone and a could have in the first and come on the sures, and i could be sure, and the bottle feeper left as was the same creaking beggar-mosther surprise to the house, and the doctor as a breath of the stockade, and had no ship's men and board the rest
# ----- temperature: 1.0
# ----- Generating with seed: " replied captain smollett. "easy with th"
#  replied captain smollett. "easy with the gun," cried the schooder work noside and deadon, as
# mike, silver
# ay got the cince, to mokein other before him in with a dice and never heard foured the sfores, wher it with her east that treefeg sailing out about that we not unded their suronsioned the doctor's lookaring the last were
# porargity for the moon troa, shipp of try.
#
# "come
# house sleep to what't he's doctor livesey before him.
# ----- temperature: 1.2
# ----- Generating with seed: " replied captain smollett. "easy with th"
#  replied captain smollett. "easy with the h.-wastmy! you've , echeven me,                  .    ."
#
# "nock if you land," said hight, "he had mn
# that was about down. i walast,
# "plie, haw heil ho."sfo'
# the procesion, he had you have ingest
# a't captain, "i have his last forght surprising."
#
# at
# yousted like straight it if by the doctor."
#
# when i had ea' wick i is, likely
# beaw
# you're to a little your comraled."
#
# so xotly lowing
# 1035/1035 [==============================] - 111s 107ms/step - loss: 1.1531
# Epoch 59/60
# 1035/1035 [==============================] - ETA: 0s - loss: 1.1479******************************************************
# ----- Generating text after Epoch: 58
# ----- temperature: 0.2
# ----- Generating with seed: " wondered, in my heart, that he should s"
#  wondered, in my heart, that he should see the captain of the blockhouse, and the chief of the ship was a signal betied of the rest of the worst. the captain of the blockhouse, and the first the chief of the boatswain of the blockhouse, and the color the captain of the blockhouse, and the captain of the worst of the boats, and the both were all the captain of the blockhouse, and the companions of the hour way were at the big of the bloc
# ----- temperature: 0.5
# ----- Generating with seed: " wondered, in my heart, that he should s"
#  wondered, in my heart, that he should see the treasure."
#
# "if you sew way, you see, and all my life-to first sail the way of his project gutenberg-tm electroused behind, and the ship inlets were at last
#
# ----- temperature: 1.0
# ----- Generating with seed: " wondered, in my heart, that he should s"
#  wondered, in my heart, that he should screaper purighting the words shipt and moke two fice the
# nible way is a long diectify of sail surprists here island like sleep
# the captain thought
# ever, he suddenly their puragnase and as a ne--a id_ fo'rror with a le, laboned had silver, and i a cutlciag, particulously thirture away up to are of cobass under
# hold this waited from the deck, and a consot thumbs! the
# lead of the popped.
# the be
# ----- temperature: 1.2
# ----- Generating with seed: " wondered, in my heart, that he should s"
#  wondered, in my heart, that he should say
# griwled blows.
#
# "por," fohn, up," says
# prodical tic a-should me don't
# _hisplanind the fine cain, ; seed the captain, youtling boandly, and a regry alrad, loe all onferss my inwusperush sorturation of mights, and again, coycre."
#
# "the bour camp's nou
# lool
# sey you way perish lie--du'tly scattering over thw
# thin several felling this throse with him, and wh, he was o
# the illustreal his s
# 1035/1035 [==============================] - 111s 107ms/step - loss: 1.1479
# Epoch 60/60
# 1035/1035 [==============================] - ETA: 0s - loss: 1.1458******************************************************
# ----- Generating text after Epoch: 59
# ----- temperature: 0.2
# ----- Generating with seed: "ci, studio graphix, inc.
#
#  random hous"
# ci, studio graphix, inc.
#
#  random house and seemed to the sailor, and the same captain of the sand hard of the sailor, and the same time i was started in the dead with her way of the stockade, and the next continued and the sand to the sailor. the sand of the treasure island, and the sight of the same time, and then we saw all the sand in the captain and the pirates of the same time of the same captain of the stockade, and then we sai
# ----- temperature: 0.5
# ----- Generating with seed: "ci, studio graphix, inc.
#
#  random hous"
# ci, studio graphix, inc.
#
#  random house, and the sailing their old waters, and the days, still for my life; "landy," said the captain, "i don't been of black dog."
#
# "well, is not
# not i could not sey it was a start here him they come ashore of money saying trivally on the old is that way, and the stern and bristol was as we had a come of the sure
# at the old sandlearing out of the distance, and the cook
# plice of the black spot man.
# ----- temperature: 1.0
# ----- Generating with seed: "ci, studio graphix, inc.
#
#  random hous"
# ci, studio graphix, inc.
#
#  random house, and there we teluss, like
# distant
#
#
# on the down.
#
# "no," says the first, "here'nd it la; "i addered, sir, not my hear," though," he said at the schoon.
#
# "silver," though of peint," discussion to the glanders, and as on his agum.
#
# "well, sirt,' says ie, and no men you tell usy clear about this
# electronoce, do a
# samels? as the assy kish this for ship's flasned other crimparasion crosse
# ----- temperature: 1.2
# ----- Generating with seed: "ci, studio graphix, inc.
#
#  random hous"
# ci, studio graphix, inc.
#
#  random house
# toge
# and geess,
#   oncimen this hemnt. lease beroobint.
#
# appripended, who hid here in day,
# asrade. so i had gove your cancausin. all," "burne?" he sageh in one
# parks.
#
#     expect a murrate good, _hishs, that be
# ni"ber,
# thunty, but i
# saw a figute wheerer treasure of at wick they
# acrume for slipped bit fallining nerross spobs. deathed his rooming to the log-huopim.
#
# "dimbe, si'll rou
# 1035/1035 [==============================] - 111s 107ms/step - loss: 1.1458
